# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists("secret_twitter_credentials.pkl"):
    Twitter = {}
    Twitter["Consumer Key"] = "pZsFxQc02cs1WEjJZUKaLyk18"
    Twitter["Consumer Secret"] = "lPS8WoyFJCGDOL6LdEwnM0chBq2pmkVaYSPr8xVWeRWVM9B9Yk"
    Twitter["Access Token"] = "1145666867480186885-vKClUIjIOLpb7DlnV2cIIN9nQxBRC5"
    Twitter["Access Token Secret"] = "ErHsrD2ttBEEnVAU0ATMmnvHowj8OW4KC5X1KX6DheKDu"
    with open("secret_twittter_credential.pkl","wb") as f:
             pickle.dump(Twitter,f)
else:
    Twitters = pickle.load(popen("secret_twitter-_credentials.pkl","rb"))

# %% [markdown]
# Install the twitter package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\user\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ##  Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])
twitter_api = twitter.Twitter(auth = auth)

# Nothing to see by displaying twitter_api except that it now  a defined variable


print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000020869D34CC8>

# %% [markdown]
# ## Example 2: Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID= 2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id = LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#virüstürkiyede',
#     'url': 'http://twitter.com/search?q=%23vir%C3%BCst%C3%BCrkiyede',
#     'promoted_content': None,
#     'query': '%23vir%C3%BCst%C3%BCrkiyede',
#     'tweet_volume': 35813},
#    {'name': 'センバツ中止',
#     'url': 'http://twitter.com/search?q=%E3%82%BB%E3%83%B3%E3%83%90%E3%83%84%E4%B8%AD%E6%AD%A2',
#     'promoted_content': None,
#     'query': '%E3%82%BB%E3%83%B3%E3%83%90%E3%83%84%E4%B8%AD%E6%AD%A2',
#     'tweet_volume': 53621},
#    {'name': 'あなたのサークル',
#     'url': 'http://twitter.com/search?q=%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%82%B5%E3%83%BC%E3%82%AF%E3%83%AB',
#     'promoted_content': None,
#     'query': '%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E3%82%B5%E3%83%BC%E3%82%AF%E3%83%AB',
#     'tweet_volume': 121710},
#    {'name': '#Hの文字でわかる性欲診断',
#     'url': 'http://twitter.com/search?q=%23H%E3%81%AE%E6%96%87%E5%AD%97%E3%81%A7%E3%82%8F%E3%81%8B%E3%82%8B%E6%80%A7%E6%AC%B2%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23H%E3%81%AE%E6%96%87%E5%AD%97%E3%81%A7%E3%82%8F%E3%81%8B%E3%82%8B%E6%80%A7%E6%AC%B2%E8%A8%BA%E6%96%AD',
#     'tweet_volume': None},
#    {'name': '#キティちゃんのお絵かき',
#     'url': 'http://twitter.com/search?q=%23%E3%82%AD%E3%83%86%E3%82%A3%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E3%81%8A%E7%B5%B5%E3%81%8B%E3%81%8D',
#     'promoted_content': None,
#     'query': '%23%E3%82%AD%E3%83%86%E3%82%A3%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E3%81%8A%E7%B5%B5%E3%81%8B%E3%81%8D',
#     'tweet_volume': 24078},
#    {'name': '#BerkinElvan',
#     'url': 'http://twitter.com/search?q=%23BerkinElvan',
#     'promoted_content': None,
#     'query': '%23BerkinElvan',
#     'tweet_volume': 12791},
#    {'name': 'コミケ',
#     'url': 'http://twitter.com/search?q=%E3%82%B3%E3%83%9F%E3%82%B1',
#     'promoted_content': None,
#     'query': '%E3%82%B3%E3%83%9F%E3%82%B1',
#     'tweet_volume': 50262},
#    {'name': 'enuygunfiyatta ttverilir',
#     'url': 'http://twitter.com/search?q=%22enuygunfiyatta+ttverilir%22',
#     'promoted_content': None,
#     'query': '%22enuygunfiyatta+ttverilir%22',
#     'tweet_volume': None},
#    {'name': '#東日本大震災から9年',
#     'url': 'http://twitter.com/search?q=%23%E6%9D%B1%E6%97%A5%E6%9C%AC%E5%A4%A7%E9%9C%87%E7%81%BD%E3%81%8B%E3%82%899%E5%B9%B4',
#     'promoted_content': None,
#     'query': '%23%E6%9D%B1%E6%97%A5%E6%9C%AC%E5%A4%A7%E9%9C%87%E7%81%BD%E3%81%8B%E3%82%899%E5%B9%B4',
#     'tweet_volume': 185879},
#    {'name': '選抜中止',
#     'url': 'http://twitter.com/search?q=%E9%81%B8%E6%8A%9C%E4%B8%AD%E6%AD%A2',
#     'promoted_content': None,
#     'query': '%E9%81%B8%E6%8A%9C%E4%B8%AD%E6%AD%A2',
#     'tweet_volume': 12674},
#    {'name': 'ド変態性癖ビンゴ',
#     'url': 'http://twitter.com/search?q=%E3%83%89%E5%A4%89%E6%85%8B%E6%80%A7%E7%99%96%E3%83%93%E3%83%B3%E3%82%B4',
#     'promoted_content': None,
#     'query': '%E3%83%89%E5%A4%89%E6%85%8B%E6%80%A7%E7%99%96%E3%83%93%E3%83%B3%E3%82%B4',
#     'tweet_volume': None},
#    {'name': 'ファンタズミック',
#     'url': 'http://twitter.com/search?q=%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%BA%E3%83%9F%E3%83%83%E3%82%AF',
#     'promoted_content': None,
#     'query': '%E3%83%95%E3%82%A1%E3%83%B3%E3%82%BF%E3%82%BA%E3%83%9F%E3%83%83%E3%82%AF',
#     'tweet_volume': 14766},
#    {'name': 'tacubaya',
#     'url': 'http://twitter.com/search?q=tacubaya',
#     'promoted_content': None,
#     'query': 'tacubaya',
#     'tweet_volume': 49704},
#    {'name': '選抜高校野球',
#     'url': 'http://twitter.com/search?q=%E9%81%B8%E6%8A%9C%E9%AB%98%E6%A0%A1%E9%87%8E%E7%90%83',
#     'promoted_content': None,
#     'query': '%E9%81%B8%E6%8A%9C%E9%AB%98%E6%A0%A1%E9%87%8E%E7%90%83',
#     'tweet_volume': None},
#    {'name': 'センバツ高校野球',
#     'url': 'http://twitter.com/search?q=%E3%82%BB%E3%83%B3%E3%83%90%E3%83%84%E9%AB%98%E6%A0%A1%E9%87%8E%E7%90%83',
#     'promoted_content': None,
#     'query': '%E3%82%BB%E3%83%B3%E3%83%90%E3%83%84%E9%AB%98%E6%A0%A1%E9%87%8E%E7%90%83',
#     'tweet_volume': 29009},
#    {'name': 'Bank of England',
#     'url': 'http://twitter.com/search?q=%22Bank+of+England%22',
#     'promoted_content': None,
#     'query': '%22Bank+of+England%22',
#     'tweet_volume': None},
#    {'name': '休園延長',
#     'url': 'http://twitter.com/search?q=%E4%BC%91%E5%9C%92%E5%BB%B6%E9%95%B7',
#     'promoted_content': None,
#     'query': '%E4%BC%91%E5%9C%92%E5%BB%B6%E9%95%B7',
#     'tweet_volume': 46169},
#    {'name': '日本高野連',
#     'url': 'http://twitter.com/search?q=%E6%97%A5%E6%9C%AC%E9%AB%98%E9%87%8E%E9%80%A3',
#     'promoted_content': None,
#     'query': '%E6%97%A5%E6%9C%AC%E9%AB%98%E9%87%8E%E9%80%A3',
#     'tweet_volume': None},
#    {'name': 'BTS WORLD DOMINATION',
#     'url': 'http://twitter.com/search?q=%22BTS+WORLD+DOMINATION%22',
#     'promoted_content': None,
#     'query': '%22BTS+WORLD+DOMINATION%22',
#     'tweet_volume': 65748},
#    {'name': 'ニコ超',
#     'url': 'http://twitter.com/search?q=%E3%83%8B%E3%82%B3%E8%B6%85',
#     'promoted_content': None,
#     'query': '%E3%83%8B%E3%82%B3%E8%B6%85',
#     'tweet_volume': None},
#    {'name': '会議中止',
#     'url': 'http://twitter.com/search?q=%E4%BC%9A%E8%AD%B0%E4%B8%AD%E6%AD%A2',
#     'promoted_content': None,
#     'query': '%E4%BC%9A%E8%AD%B0%E4%B8%AD%E6%AD%A2',
#     'tweet_volume': 22336},
#    {'name': 'E3中止',
#     'url': 'http://twitter.com/search?q=E3%E4%B8%AD%E6%AD%A2',
#     'promoted_content': None,
#     'query': 'E3%E4%B8%AD%E6%AD%A2',
#     'tweet_volume': None},
#    {'name': 'ブギウギ',
#     'url': 'http://twitter.com/search?q=%E3%83%96%E3%82%AE%E3%82%A6%E3%82%AE',
#     'promoted_content': None,
#     'query': '%E3%83%96%E3%82%AE%E3%82%A6%E3%82%AE',
#     'tweet_volume': None},
#    {'name': '新エリア',
#     'url': 'http://twitter.com/search?q=%E6%96%B0%E3%82%A8%E3%83%AA%E3%82%A2',
#     'promoted_content': None,
#     'query': '%E6%96%B0%E3%82%A8%E3%83%AA%E3%82%A2',
#     'tweet_volume': 22577},
#    {'name': '高校球児',
#     'url': 'http://twitter.com/search?q=%E9%AB%98%E6%A0%A1%E7%90%83%E5%85%90',
#     'promoted_content': None,
#     'query': '%E9%AB%98%E6%A0%A1%E7%90%83%E5%85%90',
#     'tweet_volume': None},
#    {'name': '#koronavirusu',
#     'url': 'http://twitter.com/search?q=%23koronavirusu',
#     'promoted_content': None,
#     'query': '%23koronavirusu',
#     'tweet_volume': None},
#    {'name': '#EXO_Repackage_album',
#     'url': 'http://twitter.com/search?q=%23EXO_Repackage_album',
#     'promoted_content': None,
#     'query': '%23EXO_Repackage_album',
#     'tweet_volume': 46874},
#    {'name': '#11Marzo',
#     'url': 'http://twitter.com/search?q=%2311Marzo',
#     'promoted_content': None,
#     'query': '%2311Marzo',
#     'tweet_volume': None},
#    {'name': '#OnMyBlockS3',
#     'url': 'http://twitter.com/search?q=%23OnMyBlockS3',
#     'promoted_content': None,
#     'query': '%23OnMyBlockS3',
#     'tweet_volume': None},
#    {'name': '#Islamabad',
#     'url': 'http://twitter.com/search?q=%23Islamabad',
#     'promoted_content': None,
#     'query': '%23Islamabad',
#     'tweet_volume': 10821},
#    {'name': '#負けるなポケ徹',
#     'url': 'http://twitter.com/search?q=%23%E8%B2%A0%E3%81%91%E3%82%8B%E3%81%AA%E3%83%9D%E3%82%B1%E5%BE%B9',
#     'promoted_content': None,
#     'query': '%23%E8%B2%A0%E3%81%91%E3%82%8B%E3%81%AA%E3%83%9D%E3%82%B1%E5%BE%B9',
#     'tweet_volume': None},
#    {'name': '#탐라분들_그림그릴때_뭐써요',
#     'url': 'http://twitter.com/search?q=%23%ED%83%90%EB%9D%BC%EB%B6%84%EB%93%A4_%EA%B7%B8%EB%A6%BC%EA%B7%B8%EB%A6%B4%EB%95%8C_%EB%AD%90%EC%8D%A8%EC%9A%94',
#     'promoted_content': None,
#     'query': '%23%ED%83%90%EB%9D%BC%EB%B6%84%EB%93%A4_%EA%B7%B8%EB%A6%BC%EA%B7%B8%EB%A6%B4%EB%95%8C_%EB%AD%90%EC%8D%A8%EC%9A%94',
#     'tweet_volume': None},
#    {'name': '#MamaBisa',
#     'url': 'http://twitter.com/search?q=%23MamaBisa',
#     'promoted_content': None,
#     'query': '%23MamaBisa',
#     'tweet_volume': None},
#    {'name': '#SB19saPinasFM',
#     'url': 'http://twitter.com/search?q=%23SB19saPinasFM',
#     'promoted_content': None,
#     'query': '%23SB19saPinasFM',
#     'tweet_volume': 15166},
#    {'name': '#よく呟く言葉からあなたは何県民か当てる',
#     'url': 'http://twitter.com/search?q=%23%E3%82%88%E3%81%8F%E5%91%9F%E3%81%8F%E8%A8%80%E8%91%89%E3%81%8B%E3%82%89%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E4%BD%95%E7%9C%8C%E6%B0%91%E3%81%8B%E5%BD%93%E3%81%A6%E3%82%8B',
#     'promoted_content': None,
#     'query': '%23%E3%82%88%E3%81%8F%E5%91%9F%E3%81%8F%E8%A8%80%E8%91%89%E3%81%8B%E3%82%89%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AF%E4%BD%95%E7%9C%8C%E6%B0%91%E3%81%8B%E5%BD%93%E3%81%A6%E3%82%8B',
#     'tweet_volume': 19016},
#    {'name': '#ByeByeBernie',
#     'url': 'http://twitter.com/search?q=%23ByeByeBernie',
#     'promoted_content': None,
#     'query': '%23ByeByeBernie',
#     'tweet_volume': 27057},
#    {'name': '#WaspadaCegahCorona',
#     'url': 'http://twitter.com/search?q=%23WaspadaCegahCorona',
#     'promoted_content': None,
#     'query': '%23WaspadaCegahCorona',
#     'tweet_volume': 16731},
#    {'name': '#عقارك_تمويل_شراء_رهن',
#     'url': 'http://twitter.com/search?q=%23%D8%B9%D9%82%D8%A7%D8%B1%D9%83_%D8%AA%D9%85%D9%88%D9%8A%D9%84_%D8%B4%D8%B1%D8%A7%D8%A1_%D8%B1%D9%87%D9%86',
#     'promoted_content': None,
#     'query': '%23%D8%B9%D9%82%D8%A7%D8%B1%D9%83_%D8%AA%D9%85%D9%88%D9%8A%D9%84_%D8%B4%D8%B1%D8%A7%D8%A1_%D8%B1%D9%87%D9%86',
#     'tweet_volume': None},
#    {'name': '#あなたの名前を直訳すると',
#     'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%90%8D%E5%89%8D%E3%82%92%E7%9B%B4%E8%A8%B3%E3%81%99%E3%82%8B%E3%81%A8',
#     'promoted_content': None,
#     'query': '%23%E3%81%82%E3%81%AA%E3%81%9F%E3%81%AE%E5%90%8D%E5%89%8D%E3%82%92%E7%9B%B4%E8%A8%B3%E3%81%99%E3%82%8B%E3%81%A8',
#     'tweet_volume': None},
#    {'name': '#Çarşamba',
#     'url': 'http://twitter.com/search?q=%23%C3%87ar%C5%9Famba',
#     'promoted_content': None,
#     'query': '%23%C3%87ar%C5%9Famba',
#     'tweet_volume': 14806},
#    {'name': '#くらすます',
#     'url': 'http://twitter.com/search?q=%23%E3%81%8F%E3%82%89%E3%81%99%E3%81%BE%E3%81%99',
#     'promoted_content': None,
#     'query': '%23%E3%81%8F%E3%82%89%E3%81%99%E3%81%BE%E3%81%99',
#     'tweet_volume': None},
#    {'name': '#JyotiradityaMScindia',
#     'url': 'http://twitter.com/search?q=%23JyotiradityaMScindia',
#     'promoted_content': None,
#     'query': '%23JyotiradityaMScindia',
#     'tweet_volume': 26202},
#    {'name': '#_بريده',
#     'url': 'http://twitter.com/search?q=%23_%D8%A8%D8%B1%D9%8A%D8%AF%D9%87',
#     'promoted_content': None,
#     'query': '%23_%D8%A8%D8%B1%D9%8A%D8%AF%D9%87',
#     'tweet_volume': None},
#    {'name': '#FelizMiércoles',
#     'url': 'http://twitter.com/search?q=%23FelizMi%C3%A9rcoles',
#     'promoted_content': None,
#     'query': '%23FelizMi%C3%A9rcoles',
#     'tweet_volume': None},
#    {'name': '#ปังจริงจ้า',
#     'url': 'http://twitter.com/search?q=%23%E0%B8%9B%E0%B8%B1%E0%B8%87%E0%B8%88%E0%B8%A3%E0%B8%B4%E0%B8%87%E0%B8%88%E0%B9%89%E0%B8%B2',
#     'promoted_content': None,
#     'query': '%23%E0%B8%9B%E0%B8%B1%E0%B8%87%E0%B8%88%E0%B8%A3%E0%B8%B4%E0%B8%87%E0%B8%88%E0%B9%89%E0%B8%B2',
#     'tweet_volume': None},
#    {'name': '#DukungOmnibusLaw',
#     'url': 'http://twitter.com/search?q=%23DukungOmnibusLaw',
#     'promoted_content': None,
#     'query': '%23DukungOmnibusLaw',
#     'tweet_volume': None},
#    {'name': '#JeSuisSneazzy',
#     'url': 'http://twitter.com/search?q=%23JeSuisSneazzy',
#     'promoted_content': None,
#     'query': '%23JeSuisSneazzy',
#     'tweet_volume': 15780},
#    {'name': '#티비조선_갑질_출연계약서_공론화',
#     'url': 'http://twitter.com/search?q=%23%ED%8B%B0%EB%B9%84%EC%A1%B0%EC%84%A0_%EA%B0%91%EC%A7%88_%EC%B6%9C%EC%97%B0%EA%B3%84%EC%95%BD%EC%84%9C_%EA%B3%B5%EB%A1%A0%ED%99%94',
#     'promoted_content': None,
#     'query': '%23%ED%8B%B0%EB%B9%84%EC%A1%B0%EC%84%A0_%EA%B0%91%EC%A7%88_%EC%B6%9C%EC%97%B0%EA%B3%84%EC%95%BD%EC%84%9C_%EA%B3%B5%EB%A1%A0%ED%99%94',
#     'tweet_volume': 11415},
#    {'name': '#صباحات_الهلال',
#     'url': 'http://twitter.com/search?q=%23%D8%B5%D8%A8%D8%A7%D8%AD%D8%A7%D8%AA_%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84',
#     'promoted_content': None,
#     'query': '%23%D8%B5%D8%A8%D8%A7%D8%AD%D8%A7%D8%AA_%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84',
#     'tweet_volume': None},
#    {'name': '#シンデレラガールの人',
#     'url': 'http://twitter.com/search?q=%23%E3%82%B7%E3%83%B3%E3%83%87%E3%83%AC%E3%83%A9%E3%82%AC%E3%83%BC%E3%83%AB%E3%81%AE%E4%BA%BA',
#     'promoted_content': None,
#     'query': '%23%E3%82%B7%E3%83%B3%E3%83%87%E3%83%AC%E3%83%A9%E3%82%AC%E3%83%BC%E3%83%AB%E3%81%AE%E4%BA%BA',
#     'tweet_volume': None}],
#   'as_of': '2020-03-11T09:05:53Z',
#   'created_at': '2020-03-11T09:00:18Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends = local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]["trends"])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#TheBachelorFinale', 'url': 'http://twitter.com/search?q=%23TheBachelorFinale', 'promoted_content': None, 'query': '%23TheBachelorFinale', 'tweet_volume': 99082}, {'name': 'Coachella', 'url': 'http://twitter.com/search?q=Coachella', 'promoted_content': None, 'query': 'Coachella', 'tweet_volume': 200042}, {'name': 'UCSD', 'url': 'http://twitter.com/search?q=UCSD', 'promoted_content': None, 'query': 'UCSD', 'tweet_volume': 14916}, {'name': '#COVID2019', 'url': 'http://twitter.com/search?q=%23COVID2019', 'promoted_content': None, 'query': '%23COVID2019', 'tweet_volume': 352047}, {'name': 'Italy', 'url': 'http://twitter.com/search?q=Italy', 'promoted_content': None, 'query': 'Italy', 'tweet_volume': 565149}, {'name': '#SuperTuesday2', 'url': 'http://twitter.com/search?q=%23SuperTuesday2', 'promoted_content': None, 'query': '%23SuperTuesday2', 'tweet_volume': 56667}, {'name': '#OnMyBlockS3', 'url': 'http://twitter.com/search?q=%23OnMyBlockS3', 'promoted_content': None, 'query': '%23OnMyBlockS3', 'tweet_volume': None}, {'name': '#ByeByeBernie', 'url': 'http://twitter.com/search?q=%23ByeByeBernie', 'promoted_content': None, 'query': '%23ByeByeBernie', 'tweet_volume': 27057}, {'name': '3 tsa', 'url': 'http://twitter.com/search?q=%223+tsa%22', 'promoted_content': None, 'query': '%223+tsa%22', 'tweet_volume': None}, {'name': 'BTS WORLD DOMINATION', 'url': 'http://twitter.com/search?q=%22BTS+WORLD+DOMINATION%22', 'promoted_content': None, 'query': '%22BTS+WORLD+DOMINATION%22', 'tweet_volume': 65748}, {'name': 'Bank of England', 'url': 'http://twitter.com/search?q=%22Bank+of+England%22', 'promoted_content': None, 'query': '%22Bank+of+England%22', 'tweet_volume': None}, {'name': 'Shrek in Spanish', 'url': 'http://twitter.com/search?q=%22Shrek+in+Spanish%22', 'promoted_content': None, 'query': '%22Shrek+in+Spanish%22', 'tweet_volume': 59978}, {'name': 'Rout', 'url': 'http://twitter.com/search?q=Rout', 'promoted_content': None, 'query': 'Rout', 'tweet_volume': None}, {'name': 'Carville', 'url': 'http://twitter.com/search?q=Carville', 'promoted_content': None, 'query': 'Carville', 'tweet_volume': 24149}, {'name': 'Van Jones', 'url': 'http://twitter.com/search?q=%22Van+Jones%22', 'promoted_content': None, 'query': '%22Van+Jones%22', 'tweet_volume': 11885}, {'name': 'tacubaya', 'url': 'http://twitter.com/search?q=tacubaya', 'promoted_content': None, 'query': 'tacubaya', 'tweet_volume': 49704}, {'name': 'Lil Ricky', 'url': 'http://twitter.com/search?q=%22Lil+Ricky%22', 'promoted_content': None, 'query': '%22Lil+Ricky%22', 'tweet_volume': None}, {'name': 'road to kingdom', 'url': 'http://twitter.com/search?q=%22road+to+kingdom%22', 'promoted_content': None, 'query': '%22road+to+kingdom%22', 'tweet_volume': 24153}, {'name': 'Just Everywhere Already', 'url': 'http://twitter.com/search?q=%22Just+Everywhere+Already%22', 'promoted_content': None, 'query': '%22Just+Everywhere+Already%22', 'tweet_volume': None}, {'name': '1439 - michael osterholm', 'url': 'http://twitter.com/search?q=%221439+-+michael+osterholm%22', 'promoted_content': None, 'query': '%221439+-+michael+osterholm%22', 'tweet_volume': None}, {'name': 'Spy Kids', 'url': 'http://twitter.com/search?q=%22Spy+Kids%22', 'promoted_content': None, 'query': '%22Spy+Kids%22', 'tweet_volume': None}, {'name': 'Nipsey Struggle', 'url': 'http://twitter.com/search?q=%22Nipsey+Struggle%22', 'promoted_content': None, 'query': '%22Nipsey+Struggle%22', 'tweet_volume': None}, {'name': 'Aunt Gloria', 'url': 'http://twitter.com/search?q=%22Aunt+Gloria%22', 'promoted_content': None, 'query': '%22Aunt+Gloria%22', 'tweet_volume': None}, {'name': 'My Last', 'url': 'http://twitter.com/search?q=%22My+Last%22', 'promoted_content': None, 'query': '%22My+Last%22', 'tweet_volume': 45133}, {'name': 'my next', 'url': 'http://twitter.com/search?q=%22my+next%22', 'promoted_content': None, 'query': '%22my+next%22', 'tweet_volume': 24010}, {'name': 'Olympiakos', 'url': 'http://twitter.com/search?q=Olympiakos', 'pro ...

# %% [markdown]
# ## Example:3 Displaying API responses as pretty-printed JSON

# %%
import json
print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#OnMyBlockS3",
#     "url": "http://twitter.com/search?q=%23OnMyBlockS3",
#     "promoted_content": null,
#     "query": "%23OnMyBlockS3",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ByeByeBernie",
#     "url": "http://twitter.com/search?q=%23ByeByeBernie",
#     "promoted_content": null,
#     "query": "%23ByeByeBernie",
#     "tweet_volume": 27057
#    },
#    {
#     "name": "#LoseWithBiden",
#     "url": "http://twitter.com/search?q=%23LoseWithBiden",
#     "promoted_content": null,
#     "query": "%23LoseWithBiden",
#     "tweet_volume": 56220
#    },
#    {
#     "name": "#BernieWarriors",
#     "url": "http://twitter.com/search?q=%23BernieWarriors",
#     "promoted_content": null,
#     "query": "%23BernieWarriors",
#     "tweet_volume": null
#    },
#    {
#     "name": "#E32020",
#     "url": "http://twitter.com/search?q=%23E32020",
#     "promoted_content": null,
#     "query": "%23E32020",
#     "tweet_volume": null
#    },
#    {
#     "name": "3 tsa",
#     "url": "http://twitter.com/search?q=%223+tsa%22",
#     "promoted_content": null,
#     "query": "%223+tsa%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "BTS WORLD DOMINATION",
#     "url": "http://twitter.com/search?q=%22BTS+WORLD+DOMINATION%22",
#     "promoted_content": null,
#     "query": "%22BTS+WORLD+DOMINATION%22",
#     "tweet_volume": 65748
#    },
#    {
#     "name": "Bank of England",
#     "url": "http://twitter.com/search?q=%22Bank+of+England%22",
#     "promoted_content": null,
#     "query": "%22Bank+of+England%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Shrek in Spanish",
#     "url": "http://twitter.com/search?q=%22Shrek+in+Spanish%22",
#     "promoted_content": null,
#     "query": "%22Shrek+in+Spanish%22",
#     "tweet_volume": 59978
#    },
#    {
#     "name": "Rout",
#     "url": "http://twitter.com/search?q=Rout",
#     "promoted_content": null,
#     "query": "Rout",
#     "tweet_volume": null
#    },
#    {
#     "name": "Carville",
#     "url": "http://twitter.com/search?q=Carville",
#     "promoted_content": null,
#     "query": "Carville",
#     "tweet_volume": 24149
#    },
#    {
#     "name": "Van Jones",
#     "url": "http://twitter.com/search?q=%22Van+Jones%22",
#     "promoted_content": null,
#     "query": "%22Van+Jones%22",
#     "tweet_volume": 11885
#    },
#    {
#     "name": "tacubaya",
#     "url": "http://twitter.com/search?q=tacubaya",
#     "promoted_content": null,
#     "query": "tacubaya",
#     "tweet_volume": 49704
#    },
#    {
#     "name": "Lil Ricky",
#     "url": "http://twitter.com/search?q=%22Lil+Ricky%22",
#     "promoted_content": null,
#     "query": "%22Lil+Ricky%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "road to kingdom",
#     "url": "http://twitter.com/search?q=%22road+to+kingdom%22",
#     "promoted_content": null,
#     "query": "%22road+to+kingdom%22",
#     "tweet_volume": 24153
#    },
#    {
#     "name": "Just Everywhere Already",
#     "url": "http://twitter.com/search?q=%22Just+Everywhere+Already%22",
#     "promoted_content": null,
#     "query": "%22Just+Everywhere+Already%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "1439 - michael osterholm",
#     "url": "http://twitter.com/search?q=%221439+-+michael+osterholm%22",
#     "promoted_content": null,
#     "query": "%221439+-+michael+osterholm%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Spy Kids",
#     "url": "http://twitter.com/search?q=%22Spy+Kids%22",
#     "promoted_content": null,
#     "query": "%22Spy+Kids%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nipsey Struggle",
#     "url": "http://twitter.com/search?q=%22Nipsey+Struggle%22",
#     "promoted_content": null,
#     "query": "%22Nipsey+Struggle%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Aunt Gloria",
#     "url": "http://twitter.com/search?q=%22Aunt+Gloria%22",
#     "promoted_content": null,
#     "query": "%22Aunt+Gloria%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "My Last",
#     "url": "http://twitter.com/search?q=%22My+Last%22",
#     "promoted_content": null,
#     "query": "%22My+Last%22",
#     "tweet_volume": 45133
#    },
#    {
#     "name": "my next",
#     "url": "http://twitter.com/search?q=%22my+next%22",
#     "promoted_content": null,
#     "query": "%22my+next%22",
#     "tweet_volume": 24010
#    },
#    {
#     "name": "Olympiakos",
#     "url": "http://twitter.com/search?q=Olympiakos",
#     "promoted_content": null,
#     "query": "Olympiakos",
#     "tweet_volume": 10470
#    },
#    {
#     "name": "The Math",
#     "url": "http://twitter.com/search?q=%22The+Math%22",
#     "promoted_content": null,
#     "query": "%22The+Math%22",
#     "tweet_volume": 35727
#    },
#    {
#     "name": "Michigan",
#     "url": "http://twitter.com/search?q=Michigan",
#     "promoted_content": null,
#     "query": "Michigan",
#     "tweet_volume": 575192
#    },
#    {
#     "name": "Warzone",
#     "url": "http://twitter.com/search?q=Warzone",
#     "promoted_content": null,
#     "query": "Warzone",
#     "tweet_volume": 154481
#    },
#    {
#     "name": "Italy",
#     "url": "http://twitter.com/search?q=Italy",
#     "promoted_content": null,
#     "query": "Italy",
#     "tweet_volume": 565149
#    },
#    {
#     "name": "ar-14",
#     "url": "http://twitter.com/search?q=ar-14",
#     "promoted_content": null,
#     "query": "ar-14",
#     "tweet_volume": 107228
#    },
#    {
#     "name": "#WednesdayWisdom",
#     "url": "http://twitter.com/search?q=%23WednesdayWisdom",
#     "promoted_content": null,
#     "query": "%23WednesdayWisdom",
#     "tweet_volume": 17413
#    },
#    {
#     "name": "#IMayBeDrunkBut",
#     "url": "http://twitter.com/search?q=%23IMayBeDrunkBut",
#     "promoted_content": null,
#     "query": "%23IMayBeDrunkBut",
#     "tweet_volume": null
#    },
#    {
#     "name": "#whyiwasleftonread",
#     "url": "http://twitter.com/search?q=%23whyiwasleftonread",
#     "promoted_content": null,
#     "query": "%23whyiwasleftonread",
#     "tweet_volume": null
#    },
#    {
#     "name": "#barb",
#     "url": "http://twitter.com/search?q=%23barb",
#     "promoted_content": null,
#     "query": "%23barb",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NCT127RODEO",
#     "url": "http://twitter.com/search?q=%23NCT127RODEO",
#     "promoted_content": null,
#     "query": "%23NCT127RODEO",
#     "tweet_volume": 29625
#    },
#    {
#     "name": "#TeamBarb",
#     "url": "http://twitter.com/search?q=%23TeamBarb",
#     "promoted_content": null,
#     "query": "%23TeamBarb",
#     "tweet_volume": null
#    },
#    {
#     "name": "#yangang",
#     "url": "http://twitter.com/search?q=%23yangang",
#     "promoted_content": null,
#     "query": "%23yangang",
#     "tweet_volume": null
#    },
#    {
#     "name": "#tobuildconfidence",
#     "url": "http://twitter.com/search?q=%23tobuildconfidence",
#     "promoted_content": null,
#     "query": "%23tobuildconfidence",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RejectedDisneyShows",
#     "url": "http://twitter.com/search?q=%23RejectedDisneyShows",
#     "promoted_content": null,
#     "query": "%23RejectedDisneyShows",
#     "tweet_volume": null
#    },
#    {
#     "name": "#TheReasonCATSFailed",
#     "url": "http://twitter.com/search?q=%23TheReasonCATSFailed",
#     "promoted_content": null,
#     "query": "%23TheReasonCATSFailed",
#     "tweet_volume": null
#    },
#    {
#     "name": "#newamsterdam",
#     "url": "http://twitter.com/search?q=%23newamsterdam",
#     "promoted_content": null,
#     "query": "%23newamsterdam",
#     "tweet_volume": null
#    },
#    {
#     "name": "#EricNaminSF",
#     "url": "http://twitter.com/search?q=%23EricNaminSF",
#     "promoted_content": null,
#     "query": "%23EricNaminSF",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CloseCuny",
#     "url": "http://twitter.com/search?q=%23CloseCuny",
#     "promoted_content": null,
#     "query": "%23CloseCuny",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MichaelMoore",
#     "url": "http://twitter.com/search?q=%23MichaelMoore",
#     "promoted_content": null,
#     "query": "%23MichaelMoore",
#     "tweet_volume": null
#    },
#    {
#     "name": "#InkMaster",
#     "url": "http://twitter.com/search?q=%23InkMaster",
#     "promoted_content": null,
#     "query": "%23InkMaster",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DarkAges",
#     "url": "http://twitter.com/search?q=%23DarkAges",
#     "promoted_content": null,
#     "query": "%23DarkAges",
#     "tweet_volume": null
#    },
#    {
#     "name": "#COVID2019",
#     "url": "http://twitter.com/search?q=%23COVID2019",
#     "promoted_content": null,
#     "query": "%23COVID2019",
#     "tweet_volume": 352047
#    },
#    {
#     "name": "#DemExit",
#     "url": "http://twitter.com/search?q=%23DemExit",
#     "promoted_content": null,
#     "query": "%23DemExit",
#     "tweet_volume": 84873
#    },
#    {
#     "name": "#SuperTuesday2",
#     "url": "http://twitter.com/search?q=%23SuperTuesday2",
#     "promoted_content": null,
#     "query": "%23SuperTuesday2",
#     "tweet_volume": 56667
#    },
#    {
#     "name": "#MAR10Day",
#     "url": "http://twitter.com/search?q=%23MAR10Day",
#     "promoted_content": null,
#     "query": "%23MAR10Day",
#     "tweet_volume": 97001
#    },
#    {
#     "name": "#cashappwisdom",
#     "url": "http://twitter.com/search?q=%23cashappwisdom",
#     "promoted_content": null,
#     "query": "%23cashappwisdom",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BidensCognitiveDecline",
#     "url": "http://twitter.com/search?q=%23BidensCognitiveDecline",
#     "promoted_content": null,
#     "query": "%23BidensCognitiveDecline",
#     "tweet_volume": 100403
#    }
#   ],
#   "as_of": "2020-03-11T09:05:54Z",
#   "created_at": "2020-03-11T09:00:18Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example:4 Computing the intersting of two sets of trends

# %%
trends_set = {}
trends_set["world"] = set([trend["name"]
                          for trend in world_trends[0]["trends"]])

trends_set["us"] = set([trend["name"]
                       for trend in us_trends[0]["trends"]])

trends_set["san diego"] = set([trend["name"]
                              for trend in local_trends[0]["trends"]])

# %%
for loc in ["world", "us", "san diego"]:
    print(("-"*10,loc))
    print((",".join(trends_set[loc])))
# Out:
# ('----------', 'world')
# Bank of England,#EXO_Repackage_album,#MamaBisa,#東日本大震災から9年,#ปังจริงจ้า,センバツ中止,#_بريده,#탐라분들_그림그릴때_뭐써요,#티비조선_갑질_출연계약서_공론화,#صباحات_الهلال,センバツ高校野球,#koronavirusu,休園延長,#よく呟く言葉からあなたは何県民か当てる,選抜中止,新エリア,#Çarşamba,#FelizMiércoles,#シンデレラガールの人,#SB19saPinasFM,ニコ超,enuygunfiyatta ttverilir,選抜高校野球,#Hの文字でわかる性欲診断,BTS WORLD DOMINATION,tacubaya,E3中止,あなたのサークル,会議中止,#Islamabad,#ByeByeBernie,#キティちゃんのお絵かき,#あなたの名前を直訳すると,#DukungOmnibusLaw,#virüstürkiyede,ファンタズミック,#負けるなポケ徹,日本高野連,#OnMyBlockS3,高校球児,#WaspadaCegahCorona,#JeSuisSneazzy,#BerkinElvan,ブギウギ,#くらすます,ド変態性癖ビンゴ,#عقارك_تمويل_شراء_رهن,#11Marzo,#JyotiradityaMScindia,コミケ
# ('----------', 'us')
# Bank of England,Michigan,Lil Ricky,#CloseCuny,Van Jones,The Math,#MichaelMoore,road to kingdom,#LoseWithBiden,#DarkAges,#TeamBarb,Olympiakos,#cashappwisdom,Carville,BTS WORLD DOMINATION,tacubaya,Aunt Gloria,#NCT127RODEO,#ByeByeBernie,#yangang,Just Everywhere Already,Shrek in Spanish,#InkMaster,#BidensCognitiveDecline,Rout,Nipsey Struggle,#WednesdayWisdom,#EricNaminSF,#SuperTuesday2,ar-14,1439 - michael osterholm,#OnMyBlockS3,#barb,#tobuildconfidence,#IMayBeDrunkBut,#RejectedDisneyShows,#E32020,#newamsterdam,Spy Kids,my next,#BernieWarriors,#MAR10Day,Italy,#DemExit,#TheReasonCATSFailed,Warzone,#COVID2019,3 tsa,#whyiwasleftonread,My Last
# ('----------', 'san diego')
# Bank of England,Michigan,Lil Ricky,#CloseCuny,Van Jones,#TheBachelorFinale,The Math,#MichaelMoore,road to kingdom,#LoseWithBiden,#DarkAges,Olympiakos,#cashappwisdom,Carville,BTS WORLD DOMINATION,tacubaya,Coachella,Aunt Gloria,#NCT127RODEO,#ByeByeBernie,#yangang,Just Everywhere Already,UCSD,Shrek in Spanish,#InkMaster,Rout,Nipsey Struggle,#BidensCognitiveDecline,#WednesdayWisdom,#SuperTuesday2,#EricNaminSF,ar-14,1439 - michael osterholm,#OnMyBlockS3,#tobuildconfidence,#RejectedDisneyShows,#IMayBeDrunkBut,#E32020,#newamsterdam,Spy Kids,my next,#BernieWarriors,#MAR10Day,Italy,#DemExit,Warzone,#COVID2019,3 tsa,#whyiwasleftonread,My Last

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'Bank of England', '#ByeByeBernie', '#OnMyBlockS3', 'BTS WORLD DOMINATION', 'tacubaya'}
# ('==========', 'intersection of us and san-diego')
# {'Bank of England', 'Michigan', 'Lil Ricky', '#CloseCuny', 'Van Jones', 'The Math', '#MichaelMoore', 'road to kingdom', '#LoseWithBiden', '#DarkAges', 'Olympiakos', '#cashappwisdom', 'Carville', 'BTS WORLD DOMINATION', 'Aunt Gloria', 'tacubaya', '#NCT127RODEO', '#ByeByeBernie', '#yangang', 'Just Everywhere Already', 'Shrek in Spanish', '#InkMaster', '#BidensCognitiveDecline', 'Rout', 'Nipsey Struggle', '#WednesdayWisdom', '#EricNaminSF', '#SuperTuesday2', 'ar-14', '1439 - michael osterholm', '#OnMyBlockS3', '#tobuildconfidence', '#RejectedDisneyShows', '#IMayBeDrunkBut', '#E32020', '#newamsterdam', 'Spy Kids', 'my next', '#BernieWarriors', '#MAR10Day', 'Italy', '#DemExit', 'Warzone', '#COVID2019', '3 tsa', '#whyiwasleftonread', 'My Last'}

# %% [markdown]
# ## Example 5: Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = "#MTVAwards"
# topics = "#HoweAwardsxMG"

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets
search_results = twitter_api.search.tweets(q = q, count = number)
statuses = search_results["statuses"]

# %%
len(statuses)
# Out:
# 67

# %%
print(statuses)
# Out:
# [{'created_at': 'Wed Mar 11 04:36:40 +0000 2020', 'id': 1237598291728072704, 'id_str': '1237598291728072704', 'text': 'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU', 'truncated': False, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [50, 60]}], 'symbols': [], 'user_mentions': [{'screen_name': 'cxhupdates', 'name': 'CHLOE X HALLE UPDATES', 'id': 983789784182280192, 'id_str': '983789784182280192', 'indices': [3, 14]}], 'urls': [], 'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [61, 84], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cZHo1RiYxU', 'display_url': 'pic.twitter.com/cZHo1RiYxU', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911'}]}, 'extended_entities': {'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [61, 84], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cZHo1RiYxU', 'display_url': 'pic.twitter.com/cZHo1RiYxU', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 212345, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2'}, {'bitrate': 320000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2'}]}, 'additional_media_info': {'title': '', 'description': '', 'embeddable': True, 'monetizable': True, 'source_user': {'id': 2367911, 'id_str': '2367911', 'name': 'MTV', 'screen_name': 'MTV', 'location': 'NYC', 'description': 'Let me make you a mixtape', 'url': 'https://t.co/yyniasrs2z', 'entities': {'url': {'urls': [{'url': 'https://t.co/yyniasrs2z', 'expanded_url': 'http://mtv.com', 'display_url': 'mtv.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 15826826, 'friends_count': 31526, 'listed_count': 31530, 'created_at': 'Mon Mar 26 22:30:49 +0000 2007', 'favourites_count': 19842, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 287523, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_norm ...

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 46

# %%
[s["text"] for s in search_results["statuses"]]
# Out:
# ['RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTVteenwolf: ✨ me and my pack watching the #MTVAwards tonight at 9/8c ✨ https://t.co/ERQpzN9zWt',
#  'RT @HugoGloss: Noah, mozão, vem cá pra eu ver se você tem o melhor beijo mesmo! Kkk #MTVAwards',
#  'RT @thecwban: Rebola assim perto de mim que eu não respondo pelos meus atos\n AMÉM CAMILA CABELLO \n#MTVAwards https://t.co/jfAJFvM9TS',
#  'RT @GettyVIP: They’re here!  Johnny, Haechan, Mark, Jaehyun, Taeyong, Yuta, Taeil, and Doyoung of NCT 127 pose at the 2019 MTV EMAs in Sevi…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: @CW_Riverdale did you hear the news? #riverdale has been nominated at the 2018 #mtvawards! cast your votes at https://t.co/B6c16HK…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar…",
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar…",
#  "WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the… https://t.co/YgmzN4NOFx",
#  'Nuff said...\nlink up in bio \nmore👇\n#applemusic\n#tidal #spotify\n #BETawards  #MTVawards  #rightjust #Jamaljoseph… https://t.co/5Kw14SxMRg',
#  'RT @WolverineMovie: Like father, like daughter. @RealHughJackman &amp; @DafneKeen win #MTVAwards for Best Duo. #Logan https://t.co/yKnXIWc3kn',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'Out of all the #popvinylfigures we got think this may be our favourite #mtv #moonperson #spaceman #MTVawards https://t.co/EPiFwFLhyX',
#  'RT @MTVAwards: Killer on the carpet, killer in the ring. @BeckyLynchWWE 👠🥊 \n\nLess than an hour until the #MTVAwards ❗️9p on @MTV 🙌 https://…',
#  'RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at the #MTVAwards over years will always be CUTE AS HECK! Catch the show Monday, June 17th at…',
#  'Los #SpotifyAwards2020 son los nuevos #MtvAwards cuando lo hacían en el palacio de los deportes.',
#  'RT @daenerwszx: O que essa obra de arte esta fazendo fora do museu #MTVAwards https://t.co/SkMSBCKivn',
#  'RT @daenerwszx: ESSA MULHER É MARAVILHOSA, AMÉM KATHERINE LANGFORD  #MTVAwards https://t.co/7dgW0dc7R1',
#  'RT @daenerwszx: tyler posey tirando foto com os fãs na chuva é a minha religião  #MTVAwards https://t.co/KnZIoQSsvR',
#  'RT @daenerwszx: #MTVAwards https://t.co/MrNqggTNOf',
#  'RT @daenerwszx: UM ELENCO MARAVILHOSO DESSES BICHO  #MTVAwards https://t.co/rOshAWSk3P',
#  'Antes era los #MTvAwards y ahora la plataforma con mayor influencia en #Musica. Los #SpotifyAwards no son solo un e… https://t.co/PNFqifomFN',
#  'El artista más escuchado de los #SpotifyAwards2020 es Bad Bunny.\n\nEn mi época, Madonna la artista que la rompió en los #MTVAwards de los 80.',
#  'Los #SpotifyAwards un intento de lo que eran los #mtvawards',
#  "RT @MTVAwards: From @lizzo to @brielarson and more...here are the BEST audience reactions of the 2019 #MTVAwards\n\nFind out what they're rea…",
#  'RT @MTVAwards: 😱MOST FRIGHTENED PERFORMANCE GOES TO....😱\n\n#SandraBullock in "Bird Box" #MTVAwards https://t.co/P2qNbSfZBQ',
#  'RT @sanbullockof: SOCORRO MDS AAAAAA #MTVAwards https://t.co/jSEoQOqNEh',
#  'RT @MTV: "Family is what you fight for, family is what you protect. What you see in this film is exactly what Mommy would do for you." -San…',
#  'RT @MTV: Is it too late for Sandra Bullock to adopt me?! #MTVAwards https://t.co/Qx6sUB9Xbx',
#  'RT @sanbullockof: Gente qual a outra categoria que a Sandra está concorrendo? #MTVAwards',
#  'RT @sanbullockof: Vocês viram a cara da Melissa vendo a Sandra falar AAAA ela admira muito a sandy 🤧 #MTVAwards',
#  'RT @sanbullockof: VOCÊS VIRAM O BRYAN AAAAAA LINDO MDS #MTVAwards',
#  'RT @MTVAwards: GIVE IT UP FOR ALL THESE LADIES 👏  \n\nWhat would you do to sit at this table? #MTVAwards https://t.co/aubaNfy2x0',
#  'RT @sanbullockof: A PRÓXIMA CATEGORIA É A QUE A SANDRA ESTÁ CONCORRENDO AAAAAA NERVOSA #MTVAwards',
#  'RT @MTVBrasil: E quem vai levar para casa o prêmio de MELHOR ATUAÇÃO ASSUSTADA é a linda da Sandra Bullock! 👏👏👏  #MTVAwards https://t.co/ke…',
#  'RT @CaptMarvelBR: 📹 | O PESO DESSE VÍDEO!\n\nSandra Bullock grata pelo reconhecimento do seu trabalho, o que a possibilita levar seu filho, f…',
#  'RT @sanbullockof: BOA NOITE FANDOM ATÉ O OSCAR KKKK #MTVAwards https://t.co/Ryhvz4sVeu',
#  'RT @etnow: Sandra Bullock reveals she made Bird Box for her kids and her family 😭 #MTVAwards https://t.co/8P4Uycd1GM',
#  'RT @MTVAwards: #SandraBullock dedicated her #MTVAward for Most Frightened Performance in "Bird Box" to her family 💖\n\n#MTVAwards https://t.c…',
#  'RT @LHHRealitea: #LHHATL WONNNN!!!!!!!! 🔥🙌🏽 #MTVAwards #LHHATL https://t.co/ood4yx8ld7',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  "Checklist- Normani  \nThis song should've gotten more promo then we would've gotten more performances looked this… https://t.co/2PmcklmIdT",
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @TheRock: Thanks man. Inspired tears are a good thing. Now go have some tequila 🥃 \n#MTVAwards https://t.co/zk7jmYBomu',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @soniagracemusic: #MTVAwards\nIn honor of the #VMAs #MTVVMAs https://t.co/B6zp8yO0iX',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  "RT @MTV: 💋HAPPY VALENTINE'S DAY 💋\n\nPls enjoy these super sweet smooches from our Best Kiss winners at the #MTVAwards!!! https://t.co/pexc84…",
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…']

# %%
# Show one sample search result by slicing the list
print(json.dumps(statuses[0],indent = 1))
# Out:
# {
#  "created_at": "Wed Mar 11 04:36:40 +0000 2020",
#  "id": 1237598291728072704,
#  "id_str": "1237598291728072704",
#  "text": "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      50,
#      60
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "cxhupdates",
#     "name": "CHLOE X HALLE UPDATES",
#     "id": 983789784182280192,
#     "id_str": "983789784182280192",
#     "indices": [
#      3,
#      14
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      61,
#      84
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cZHo1RiYxU",
#     "display_url": "pic.twitter.com/cZHo1RiYxU",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      61,
#      84
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cZHo1RiYxU",
#     "display_url": "pic.twitter.com/cZHo1RiYxU",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "video",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911",
#     "video_info": {
#      "aspect_ratio": [
#       16,
#       9
#      ],
#      "duration_millis": 212345,
#      "variants": [
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#       },
#       {
#        "bitrate": 320000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#       },
#       {
#        "bitrate": 2176000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "title": "",
#      "description": "",
#      "embeddable": true,
#      "monetizable": true,
#      "source_user": {
#       "id": 2367911,
#       "id_str": "2367911",
#       "name": "MTV",
#       "screen_name": "MTV",
#       "location": "NYC",
#       "description": "Let me make you a mixtape",
#       "url": "https://t.co/yyniasrs2z",
#       "entities": {
#        "url": {
#         "urls": [
#          {
#           "url": "https://t.co/yyniasrs2z",
#           "expanded_url": "http://mtv.com",
#           "display_url": "mtv.com",
#           "indices": [
#            0,
#            23
#           ]
#          }
#         ]
#        },
#        "description": {
#         "urls": []
#        }
#       },
#       "protected": false,
#       "followers_count": 15826826,
#       "friends_count": 31526,
#       "listed_count": 31530,
#       "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#       "favourites_count": 19842,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 287523,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": true,
#       "profile_background_color": "131516",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1582150942",
#       "profile_link_color": "009999",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "EFEFEF",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "regular"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 2743071590,
#   "id_str": "2743071590",
#   "name": "Tristan",
#   "screen_name": "tj02008",
#   "location": "(he/him/his) TX",
#   "description": "bahahahahahahahaha",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 202,
#   "friends_count": 449,
#   "listed_count": 0,
#   "created_at": "Mon Aug 18 21:02:22 +0000 2014",
#   "favourites_count": 99234,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 11687,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1230524987062153217/GseMwoC5_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1230524987062153217/GseMwoC5_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/2743071590/1582214994",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": true,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jun 19 01:42:59 +0000 2018",
#   "id": 1008887836123295749,
#   "id_str": "1008887836123295749",
#   "text": "Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       34,
#       44
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [],
#    "urls": [],
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       45,
#       68
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cZHo1RiYxU",
#      "display_url": "pic.twitter.com/cZHo1RiYxU",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1008887184684822528,
#      "source_status_id_str": "1008887184684822528",
#      "source_user_id": 2367911,
#      "source_user_id_str": "2367911"
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       45,
#       68
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cZHo1RiYxU",
#      "display_url": "pic.twitter.com/cZHo1RiYxU",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "video",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "source_status_id": 1008887184684822528,
#      "source_status_id_str": "1008887184684822528",
#      "source_user_id": 2367911,
#      "source_user_id_str": "2367911",
#      "video_info": {
#       "aspect_ratio": [
#        16,
#        9
#       ],
#       "duration_millis": 212345,
#       "variants": [
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#        },
#        {
#         "bitrate": 320000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#        },
#        {
#         "bitrate": 2176000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "title": "",
#       "description": "",
#       "embeddable": true,
#       "monetizable": true,
#       "source_user": {
#        "id": 2367911,
#        "id_str": "2367911",
#        "name": "MTV",
#        "screen_name": "MTV",
#        "location": "NYC",
#        "description": "Let me make you a mixtape",
#        "url": "https://t.co/yyniasrs2z",
#        "entities": {
#         "url": {
#          "urls": [
#           {
#            "url": "https://t.co/yyniasrs2z",
#            "expanded_url": "http://mtv.com",
#            "display_url": "mtv.com",
#            "indices": [
#             0,
#             23
#            ]
#           }
#          ]
#         },
#         "description": {
#          "urls": []
#         }
#        },
#        "protected": false,
#        "followers_count": 15826826,
#        "friends_count": 31526,
#        "listed_count": 31530,
#        "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#        "favourites_count": 19842,
#        "utc_offset": null,
#        "time_zone": null,
#        "geo_enabled": true,
#        "verified": true,
#        "statuses_count": 287523,
#        "lang": null,
#        "contributors_enabled": false,
#        "is_translator": false,
#        "is_translation_enabled": true,
#        "profile_background_color": "131516",
#        "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#        "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#        "profile_background_tile": true,
#        "profile_image_url": "http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#        "profile_image_url_https": "https://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#        "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1582150942",
#        "profile_link_color": "009999",
#        "profile_sidebar_border_color": "FFFFFF",
#        "profile_sidebar_fill_color": "EFEFEF",
#        "profile_text_color": "333333",
#        "profile_use_background_image": true,
#        "has_extended_profile": false,
#        "default_profile": false,
#        "default_profile_image": false,
#        "following": false,
#        "follow_request_sent": false,
#        "notifications": false,
#        "translator_type": "regular"
#       }
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 983789784182280192,
#    "id_str": "983789784182280192",
#    "name": "CHLOE X HALLE UPDATES",
#    "screen_name": "cxhupdates",
#    "location": "",
#    "description": "news and updates on @chloexhalle.",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 5189,
#    "friends_count": 9,
#    "listed_count": 19,
#    "created_at": "Tue Apr 10 19:32:17 +0000 2018",
#    "favourites_count": 1333,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": false,
#    "verified": false,
#    "statuses_count": 2229,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "000000",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1217525163702542337/ejkpQqsT_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1217525163702542337/ejkpQqsT_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/983789784182280192/1579115614",
#    "profile_link_color": "ABB8C2",
#    "profile_sidebar_border_color": "000000",
#    "profile_sidebar_fill_color": "000000",
#    "profile_text_color": "000000",
#    "profile_use_background_image": false,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 726,
#   "favorite_count": 1444,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 726,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# lt of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t["retweet_count"])
print(t["retweeted"])
# Out:
# 726
# False

# %% [markdown]
# ## Example 6: Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [status["text"]
               for status in statuses]

screen_names = [user_mention["screen_name"]
               for status in statuses
                   for user_mention in status["entities"]["user_mentions"]]

hashtags = [ hashtag["text"]
           for status in statuses
               for hashtag in status["entities"]["hashtags"] ]

# compute a collection of all words from all tweets
words = [w
          for t in status_texts
               for w in t.split()]

# %%
# Exploring the first 5 items for each.....

print(json.dumps(status_texts[0:5], indent =1))
print(json.dumps(screen_names[0:5], indent =1))
print(json.dumps(hashtags[0:5], indent =1))
print(json.dumps(words[0:5], indent =1))
# Out:
# [
#  "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "RT @MTVteenwolf: \u2728 me and my pack watching the #MTVAwards tonight at 9/8c \u2728 https://t.co/ERQpzN9zWt",
#  "RT @HugoGloss: Noah, moz\u00e3o, vem c\u00e1 pra eu ver se voc\u00ea tem o melhor beijo mesmo! Kkk #MTVAwards",
#  "RT @thecwban: Rebola assim perto de mim que eu n\u00e3o respondo pelos meus atos\n AM\u00c9M CAMILA CABELLO \n#MTVAwards https://t.co/jfAJFvM9TS",
#  "RT @GettyVIP: They\u2019re here!  Johnny, Haechan, Mark, Jaehyun, Taeyong, Yuta, Taeil, and Doyoung of NCT 127 pose at the 2019 MTV EMAs in Sevi\u2026"
# ]
# [
#  "cxhupdates",
#  "MTVteenwolf",
#  "HugoGloss",
#  "thecwban",
#  "GettyVIP"
# ]
# [
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards",
#  "MTVAwards"
# ]
# [
#  "RT",
#  "@cxhupdates:",
#  "Chloe",
#  "and",
#  "Halle"
# ]

# %% [markdown]
# ## Example 7: Creating a basic  frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words,screen_names,hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 38), ('#MTVAwards', 31), ('the', 20), ('at', 16), ('a', 10), ('de', 7), ('@MTVAwards:', 7), ('los', 7), ('and', 6), ('que', 6)]
#
# [('MTV', 7), ('MTVAwards', 7), ('sanbullockof', 6), ('daenerwszx', 5), ('MTVteenwolf', 2), ('jadapsmith', 2), ('cxhupdates', 1), ('HugoGloss', 1), ('thecwban', 1), ('GettyVIP', 1)]
#
# [('MTVAwards', 33), ('mtvawards', 3), ('InternationalWomensDay', 2), ('MTVawards', 2), ('SpotifyAwards2020', 2), ('SpotifyAwards', 2), ('SandraBullock', 2), ('LHHATL', 2), ('riverdale', 1), ('applemusic', 1)]

# %% [markdown]
# ## Example 8: Creating a prettprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (("Word",words),
                   ("Screen name",screen_names),
                   ("Hashtag",hashtags)):
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     38
# #MTVAwards           |     31
# the                  |     20
# at                   |     16
# a                    |     10
# de                   |      7
# @MTVAwards:          |      7
# los                  |      7
# and                  |      6
# que                  |      6
#
#     Screen name      | Count
# ****************************************
# MTV                  |      7
# MTVAwards            |      7
# sanbullockof         |      6
# daenerwszx           |      5
# MTVteenwolf          |      2
# jadapsmith           |      2
# cxhupdates           |      1
# HugoGloss            |      1
# thecwban             |      1
# GettyVIP             |      1
#
#       Hashtag        | Count
# ****************************************
# MTVAwards            |     33
# mtvawards            |      3
# InternationalWomensDay |      2
# MTVawards            |      2
# SpotifyAwards2020    |      2
# SpotifyAwards        |      2
# SandraBullock        |      2
# LHHATL               |      2
# riverdale            |      1
# applemusic           |      1

# %% [markdown]
# ## Example 9: Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# we can build another prettyprint function to print entire tweet with their retweet count.

# %% [markdown]
# we also want to split the text of the tweet in up to 3 times if neeeded

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen name", "Text"))
    print("*"*60)
    for count, screen_name,text in list_of_tuples:
        print(row_template.format(count, screen_name,text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# slice off the first 5 from the sorted results and display each item in 

prettyprint_tweets(sorted(retweets, reverse = True)[:10])
# Out:
#  Count  |   Screen name   | Text
# ************************************************************
#  7517   |       MTV       | RT @MTV: Let @dylanobrien guide you through a firs
#         |                 | t look at Maze Runner: The Death Cure, exclusively
#         |                 |  for the #MTVAwards tonight at 8/7c! 💥…
#  4553   |       MTV       | RT @MTV: My queens @chloexhalle slayed their perfo
#         |                 | rmance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9
#  3311   |  dunevillenuve  | RT @dunevillenuve: chloe and halle are angels beyo
#         |                 | ncé really did bless them #mtvawards  https://t.co
#         |                 | /y2fDHMj3rs
#  2674   | WolverineMovie  | RT @WolverineMovie: Like father, like daughter. @R
#         |                 | ealHughJackman &amp; @DafneKeen win #MTVAwards for
#         |                 |  Best Duo. #Logan https://t.co/yKnXIWc3kn
#  2185   |       MTV       | RT @MTV: Is it too late for Sandra Bullock to adop
#         |                 | t me?! #MTVAwards https://t.co/Qx6sUB9Xbx
#   973   |   MTVteenwolf   | RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at t
#         |                 | he #MTVAwards over years will always be CUTE AS HE
#         |                 | CK! Catch the show Monday, June 17th at…
#   940   |    MTVAwards    | RT @MTVAwards: Killer on the carpet, killer in the
#         |                 |  ring. @BeckyLynchWWE 👠🥊 \\Less than an hour until
#         |                 |  the #MTVAwards ❗️9p on @MTV 🙌 https://…
#   918   |    GettyVIP     | RT @GettyVIP: They’re here!  Johnny, Haechan, Mark
#         |                 | , Jaehyun, Taeyong, Yuta, Taeil, and Doyoung of NC
#         |                 | T 127 pose at the 2019 MTV EMAs in Sevi…
#   898   |   MTVteenwolf   | RT @MTVteenwolf: ✨ me and my pack watching the #MT
#         |                 | VAwards tonight at 9/8c ✨ https://t.co/ERQpzN9zWt
#   852   |  CaptMarvelBR   | RT @CaptMarvelBR: 📹 | O PESO DESSE VÍDEO!\\Sandra
#         |                 | Bullock grata pelo reconhecimento do seu trabalho,
#         |                 |  o que a possibilita levar seu filho, f…
