# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists("secret_twitter_credentials.pkl"):
    Twitter = {}
    Twitter["Consumer Key"] = "pZsFxQc02cs1WEjJZUKaLyk18"
    Twitter["Consumer Secret"] = "lPS8WoyFJCGDOL6LdEwnM0chBq2pmkVaYSPr8xVWeRWVM9B9Yk"
    Twitter["Access Token"] = "1145666867480186885-vKClUIjIOLpb7DlnV2cIIN9nQxBRC5"
    Twitter["Access Token Secret"] = "ErHsrD2ttBEEnVAU0ATMmnvHowj8OW4KC5X1KX6DheKDu"
    with open("secret_twittter_credential.pkl","wb") as f:
             pickle.dump(Twitters,f)
else:
    Twitters = pickle.load(popen("secret_twitter-_credentials.pkl","rb"))

# %% [markdown]
# Install the twitter package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in c:\users\user\anaconda3\lib\site-packages (1.18.0)

# %% [markdown]
# ##  Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])
twitter_api = twitter.Twitter(auth = auth)

# Nothing to see by displaying twitter_api except that it now  a defined variable


print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x0000025BDA51F3C8>

# %% [markdown]
# ## Example 2: Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [san-diego](http://woeid.rosselliot.co.nz/lookup/san%20diego%20%20ca)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID= 2487889

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id = LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'trends': [{'name': '#kuizyお絵描き診断',
#     'url': 'http://twitter.com/search?q=%23kuizy%E3%81%8A%E7%B5%B5%E6%8F%8F%E3%81%8D%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23kuizy%E3%81%8A%E7%B5%B5%E6%8F%8F%E3%81%8D%E8%A8%BA%E6%96%AD',
#     'tweet_volume': 31707},
#    {'name': 'Ortega Smith',
#     'url': 'http://twitter.com/search?q=%22Ortega+Smith%22',
#     'promoted_content': None,
#     'query': '%22Ortega+Smith%22',
#     'tweet_volume': 104487},
#    {'name': '#推しがちなキャラクターの特徴',
#     'url': 'http://twitter.com/search?q=%23%E6%8E%A8%E3%81%97%E3%81%8C%E3%81%A1%E3%81%AA%E3%82%AD%E3%83%A3%E3%83%A9%E3%82%AF%E3%82%BF%E3%83%BC%E3%81%AE%E7%89%B9%E5%BE%B4',
#     'promoted_content': None,
#     'query': '%23%E6%8E%A8%E3%81%97%E3%81%8C%E3%81%A1%E3%81%AA%E3%82%AD%E3%83%A3%E3%83%A9%E3%82%AF%E3%82%BF%E3%83%BC%E3%81%AE%E7%89%B9%E5%BE%B4',
#     'tweet_volume': 20317},
#    {'name': '#マツコの知らない世界',
#     'url': 'http://twitter.com/search?q=%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C',
#     'promoted_content': None,
#     'query': '%23%E3%83%9E%E3%83%84%E3%82%B3%E3%81%AE%E7%9F%A5%E3%82%89%E3%81%AA%E3%81%84%E4%B8%96%E7%95%8C',
#     'tweet_volume': 10762},
#    {'name': '声優おたく',
#     'url': 'http://twitter.com/search?q=%E5%A3%B0%E5%84%AA%E3%81%8A%E3%81%9F%E3%81%8F',
#     'promoted_content': None,
#     'query': '%E5%A3%B0%E5%84%AA%E3%81%8A%E3%81%9F%E3%81%8F',
#     'tweet_volume': None},
#    {'name': '#koronawirus',
#     'url': 'http://twitter.com/search?q=%23koronawirus',
#     'promoted_content': None,
#     'query': '%23koronawirus',
#     'tweet_volume': 52284},
#    {'name': '#FelizMartes',
#     'url': 'http://twitter.com/search?q=%23FelizMartes',
#     'promoted_content': None,
#     'query': '%23FelizMartes',
#     'tweet_volume': 19612},
#    {'name': '理想のキス',
#     'url': 'http://twitter.com/search?q=%E7%90%86%E6%83%B3%E3%81%AE%E3%82%AD%E3%82%B9',
#     'promoted_content': None,
#     'query': '%E7%90%86%E6%83%B3%E3%81%AE%E3%82%AD%E3%82%B9',
#     'tweet_volume': None},
#    {'name': 'スタレ',
#     'url': 'http://twitter.com/search?q=%E3%82%B9%E3%82%BF%E3%83%AC',
#     'promoted_content': None,
#     'query': '%E3%82%B9%E3%82%BF%E3%83%AC',
#     'tweet_volume': 20154},
#    {'name': 'Ollie',
#     'url': 'http://twitter.com/search?q=Ollie',
#     'promoted_content': None,
#     'query': 'Ollie',
#     'tweet_volume': 10112},
#    {'name': 'NFL 2K',
#     'url': 'http://twitter.com/search?q=%22NFL+2K%22',
#     'promoted_content': None,
#     'query': '%22NFL+2K%22',
#     'tweet_volume': None},
#    {'name': 'うまかっちゃん',
#     'url': 'http://twitter.com/search?q=%E3%81%86%E3%81%BE%E3%81%8B%E3%81%A3%E3%81%A1%E3%82%83%E3%82%93',
#     'promoted_content': None,
#     'query': '%E3%81%86%E3%81%BE%E3%81%8B%E3%81%A3%E3%81%A1%E3%82%83%E3%82%93',
#     'tweet_volume': None},
#    {'name': 'マンホール女優',
#     'url': 'http://twitter.com/search?q=%E3%83%9E%E3%83%B3%E3%83%9B%E3%83%BC%E3%83%AB%E5%A5%B3%E5%84%AA',
#     'promoted_content': None,
#     'query': '%E3%83%9E%E3%83%B3%E3%83%9B%E3%83%BC%E3%83%AB%E5%A5%B3%E5%84%AA',
#     'tweet_volume': 25589},
#    {'name': 'Chuck Norris',
#     'url': 'http://twitter.com/search?q=%22Chuck+Norris%22',
#     'promoted_content': None,
#     'query': '%22Chuck+Norris%22',
#     'tweet_volume': 10657},
#    {'name': 'DANIEL BROXANDO',
#     'url': 'http://twitter.com/search?q=%22DANIEL+BROXANDO%22',
#     'promoted_content': None,
#     'query': '%22DANIEL+BROXANDO%22',
#     'tweet_volume': 37380},
#    {'name': 'プロ野球の球場',
#     'url': 'http://twitter.com/search?q=%E3%83%97%E3%83%AD%E9%87%8E%E7%90%83%E3%81%AE%E7%90%83%E5%A0%B4',
#     'promoted_content': None,
#     'query': '%E3%83%97%E3%83%AD%E9%87%8E%E7%90%83%E3%81%AE%E7%90%83%E5%A0%B4',
#     'tweet_volume': None},
#    {'name': '#AskRicci',
#     'url': 'http://twitter.com/search?q=%23AskRicci',
#     'promoted_content': None,
#     'query': '%23AskRicci',
#     'tweet_volume': None},
#    {'name': '#恋はつづくよどこまでも',
#     'url': 'http://twitter.com/search?q=%23%E6%81%8B%E3%81%AF%E3%81%A4%E3%81%A5%E3%81%8F%E3%82%88%E3%81%A9%E3%81%93%E3%81%BE%E3%81%A7%E3%82%82',
#     'promoted_content': None,
#     'query': '%23%E6%81%8B%E3%81%AF%E3%81%A4%E3%81%A5%E3%81%8F%E3%82%88%E3%81%A9%E3%81%93%E3%81%BE%E3%81%A7%E3%82%82',
#     'tweet_volume': 16209},
#    {'name': '#คั่นกูMV',
#     'url': 'http://twitter.com/search?q=%23%E0%B8%84%E0%B8%B1%E0%B9%88%E0%B8%99%E0%B8%81%E0%B8%B9MV',
#     'promoted_content': None,
#     'query': '%23%E0%B8%84%E0%B8%B1%E0%B9%88%E0%B8%99%E0%B8%81%E0%B8%B9MV',
#     'tweet_volume': 116899},
#    {'name': '#SiJetaisMarioJe',
#     'url': 'http://twitter.com/search?q=%23SiJetaisMarioJe',
#     'promoted_content': None,
#     'query': '%23SiJetaisMarioJe',
#     'tweet_volume': None},
#    {'name': '#ThankYouNamjoon',
#     'url': 'http://twitter.com/search?q=%23ThankYouNamjoon',
#     'promoted_content': None,
#     'query': '%23ThankYouNamjoon',
#     'tweet_volume': 285788},
#    {'name': '#VaathiComing',
#     'url': 'http://twitter.com/search?q=%23VaathiComing',
#     'promoted_content': None,
#     'query': '%23VaathiComing',
#     'tweet_volume': 586050},
#    {'name': '#FKocaSağlıkçıyaMarttaAtama',
#     'url': 'http://twitter.com/search?q=%23FKocaSa%C4%9Fl%C4%B1k%C3%A7%C4%B1yaMarttaAtama',
#     'promoted_content': None,
#     'query': '%23FKocaSa%C4%9Fl%C4%B1k%C3%A7%C4%B1yaMarttaAtama',
#     'tweet_volume': 121239},
#    {'name': '#BernieSurge',
#     'url': 'http://twitter.com/search?q=%23BernieSurge',
#     'promoted_content': None,
#     'query': '%23BernieSurge',
#     'tweet_volume': 19194},
#    {'name': '#UbuhanSiDuterte',
#     'url': 'http://twitter.com/search?q=%23UbuhanSiDuterte',
#     'promoted_content': None,
#     'query': '%23UbuhanSiDuterte',
#     'tweet_volume': 10654},
#    {'name': '#MAR10Day',
#     'url': 'http://twitter.com/search?q=%23MAR10Day',
#     'promoted_content': None,
#     'query': '%23MAR10Day',
#     'tweet_volume': 14724},
#    {'name': '#TuesdayThoughts',
#     'url': 'http://twitter.com/search?q=%23TuesdayThoughts',
#     'promoted_content': None,
#     'query': '%23TuesdayThoughts',
#     'tweet_volume': 31848},
#    {'name': '#500DayswithSB19',
#     'url': 'http://twitter.com/search?q=%23500DayswithSB19',
#     'promoted_content': None,
#     'query': '%23500DayswithSB19',
#     'tweet_volume': 54022},
#    {'name': '#LobinTuketiciZirvesi',
#     'url': 'http://twitter.com/search?q=%23LobinTuketiciZirvesi',
#     'promoted_content': None,
#     'query': '%23LobinTuketiciZirvesi',
#     'tweet_volume': None},
#    {'name': '#男子は引いて女子は足して',
#     'url': 'http://twitter.com/search?q=%23%E7%94%B7%E5%AD%90%E3%81%AF%E5%BC%95%E3%81%84%E3%81%A6%E5%A5%B3%E5%AD%90%E3%81%AF%E8%B6%B3%E3%81%97%E3%81%A6',
#     'promoted_content': None,
#     'query': '%23%E7%94%B7%E5%AD%90%E3%81%AF%E5%BC%95%E3%81%84%E3%81%A6%E5%A5%B3%E5%AD%90%E3%81%AF%E8%B6%B3%E3%81%97%E3%81%A6',
#     'tweet_volume': None},
#    {'name': '#和の文字で診断',
#     'url': 'http://twitter.com/search?q=%23%E5%92%8C%E3%81%AE%E6%96%87%E5%AD%97%E3%81%A7%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23%E5%92%8C%E3%81%AE%E6%96%87%E5%AD%97%E3%81%A7%E8%A8%BA%E6%96%AD',
#     'tweet_volume': None},
#    {'name': '#نطالب_بايقاف_ابوطلال_الحمراني',
#     'url': 'http://twitter.com/search?q=%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D9%8A%D9%82%D8%A7%D9%81_%D8%A7%D8%A8%D9%88%D8%B7%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D8%AD%D9%85%D8%B1%D8%A7%D9%86%D9%8A',
#     'promoted_content': None,
#     'query': '%23%D9%86%D8%B7%D8%A7%D9%84%D8%A8_%D8%A8%D8%A7%D9%8A%D9%82%D8%A7%D9%81_%D8%A7%D8%A8%D9%88%D8%B7%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D8%AD%D9%85%D8%B1%D8%A7%D9%86%D9%8A',
#     'tweet_volume': None},
#    {'name': '#JyotiradityaScindia',
#     'url': 'http://twitter.com/search?q=%23JyotiradityaScindia',
#     'promoted_content': None,
#     'query': '%23JyotiradityaScindia',
#     'tweet_volume': 82629},
#    {'name': '#ひみ10',
#     'url': 'http://twitter.com/search?q=%23%E3%81%B2%E3%81%BF10',
#     'promoted_content': None,
#     'query': '%23%E3%81%B2%E3%81%BF10',
#     'tweet_volume': 14904},
#    {'name': '#HoweAwardsxMG',
#     'url': 'http://twitter.com/search?q=%23HoweAwardsxMG',
#     'promoted_content': None,
#     'query': '%23HoweAwardsxMG',
#     'tweet_volume': 69579},
#    {'name': '#nhk_jsclub',
#     'url': 'http://twitter.com/search?q=%23nhk_jsclub',
#     'promoted_content': None,
#     'query': '%23nhk_jsclub',
#     'tweet_volume': 20458},
#    {'name': '#うたコン',
#     'url': 'http://twitter.com/search?q=%23%E3%81%86%E3%81%9F%E3%82%B3%E3%83%B3',
#     'promoted_content': None,
#     'query': '%23%E3%81%86%E3%81%9F%E3%82%B3%E3%83%B3',
#     'tweet_volume': None},
#    {'name': '#FAAJI',
#     'url': 'http://twitter.com/search?q=%23FAAJI',
#     'promoted_content': None,
#     'query': '%23FAAJI',
#     'tweet_volume': None},
#    {'name': '#このタグを見た人は習い事歴を晒せ',
#     'url': 'http://twitter.com/search?q=%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E3%82%92%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF%E7%BF%92%E3%81%84%E4%BA%8B%E6%AD%B4%E3%82%92%E6%99%92%E3%81%9B',
#     'promoted_content': None,
#     'query': '%23%E3%81%93%E3%81%AE%E3%82%BF%E3%82%B0%E3%82%92%E8%A6%8B%E3%81%9F%E4%BA%BA%E3%81%AF%E7%BF%92%E3%81%84%E4%BA%8B%E6%AD%B4%E3%82%92%E6%99%92%E3%81%9B',
#     'tweet_volume': None},
#    {'name': '#御伽の国の舞踏会',
#     'url': 'http://twitter.com/search?q=%23%E5%BE%A1%E4%BC%BD%E3%81%AE%E5%9B%BD%E3%81%AE%E8%88%9E%E8%B8%8F%E4%BC%9A',
#     'promoted_content': None,
#     'query': '%23%E5%BE%A1%E4%BC%BD%E3%81%AE%E5%9B%BD%E3%81%AE%E8%88%9E%E8%B8%8F%E4%BC%9A',
#     'tweet_volume': None},
#    {'name': '#cheltenham2020',
#     'url': 'http://twitter.com/search?q=%23cheltenham2020',
#     'promoted_content': None,
#     'query': '%23cheltenham2020',
#     'tweet_volume': None},
#    {'name': '#推し佐藤',
#     'url': 'http://twitter.com/search?q=%23%E6%8E%A8%E3%81%97%E4%BD%90%E8%97%A4',
#     'promoted_content': None,
#     'query': '%23%E6%8E%A8%E3%81%97%E4%BD%90%E8%97%A4',
#     'tweet_volume': 14955},
#    {'name': '#SB5CANDYCRUSH_TEASER',
#     'url': 'http://twitter.com/search?q=%23SB5CANDYCRUSH_TEASER',
#     'promoted_content': None,
#     'query': '%23SB5CANDYCRUSH_TEASER',
#     'tweet_volume': 57245},
#    {'name': '#ORβITさん月が綺麗ですね',
#     'url': 'http://twitter.com/search?q=%23OR%CE%B2IT%E3%81%95%E3%82%93%E6%9C%88%E3%81%8C%E7%B6%BA%E9%BA%97%E3%81%A7%E3%81%99%E3%81%AD',
#     'promoted_content': None,
#     'query': '%23OR%CE%B2IT%E3%81%95%E3%82%93%E6%9C%88%E3%81%8C%E7%B6%BA%E9%BA%97%E3%81%A7%E3%81%99%E3%81%AD',
#     'tweet_volume': None},
#    {'name': '#RIPVuyo',
#     'url': 'http://twitter.com/search?q=%23RIPVuyo',
#     'promoted_content': None,
#     'query': '%23RIPVuyo',
#     'tweet_volume': None},
#    {'name': '#ゆるニャン',
#     'url': 'http://twitter.com/search?q=%23%E3%82%86%E3%82%8B%E3%83%8B%E3%83%A3%E3%83%B3',
#     'promoted_content': None,
#     'query': '%23%E3%82%86%E3%82%8B%E3%83%8B%E3%83%A3%E3%83%B3',
#     'tweet_volume': None},
#    {'name': '#ItaliaZonaRossa',
#     'url': 'http://twitter.com/search?q=%23ItaliaZonaRossa',
#     'promoted_content': None,
#     'query': '%23ItaliaZonaRossa',
#     'tweet_volume': 34761},
#    {'name': '#انقذو_ابو_سعد',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%86%D9%82%D8%B0%D9%88_%D8%A7%D8%A8%D9%88_%D8%B3%D8%B9%D8%AF',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%86%D9%82%D8%B0%D9%88_%D8%A7%D8%A8%D9%88_%D8%B3%D8%B9%D8%AF',
#     'tweet_volume': None},
#    {'name': '#貴方の良い所と悪い所を神様から訊いた',
#     'url': 'http://twitter.com/search?q=%23%E8%B2%B4%E6%96%B9%E3%81%AE%E8%89%AF%E3%81%84%E6%89%80%E3%81%A8%E6%82%AA%E3%81%84%E6%89%80%E3%82%92%E7%A5%9E%E6%A7%98%E3%81%8B%E3%82%89%E8%A8%8A%E3%81%84%E3%81%9F',
#     'promoted_content': None,
#     'query': '%23%E8%B2%B4%E6%96%B9%E3%81%AE%E8%89%AF%E3%81%84%E6%89%80%E3%81%A8%E6%82%AA%E3%81%84%E6%89%80%E3%82%92%E7%A5%9E%E6%A7%98%E3%81%8B%E3%82%89%E8%A8%8A%E3%81%84%E3%81%9F',
#     'tweet_volume': None},
#    {'name': '#elfinllegarácuando',
#     'url': 'http://twitter.com/search?q=%23elfinllegar%C3%A1cuando',
#     'promoted_content': None,
#     'query': '%23elfinllegar%C3%A1cuando',
#     'tweet_volume': None}],
#   'as_of': '2020-03-10T13:38:29Z',
#   'created_at': '2020-03-10T13:33:16Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
trends = local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]["trends"])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': 'UCSD', 'url': 'http://twitter.com/search?q=UCSD', 'promoted_content': None, 'query': 'UCSD', 'tweet_volume': None}, {'name': '#ThankYouNamjoon', 'url': 'http://twitter.com/search?q=%23ThankYouNamjoon', 'promoted_content': None, 'query': '%23ThankYouNamjoon', 'tweet_volume': 285788}, {'name': '#TheBachelor', 'url': 'http://twitter.com/search?q=%23TheBachelor', 'promoted_content': None, 'query': '%23TheBachelor', 'tweet_volume': 232881}, {'name': '#COVID2019', 'url': 'http://twitter.com/search?q=%23COVID2019', 'promoted_content': None, 'query': '%23COVID2019', 'tweet_volume': 590490}, {'name': 'Italy', 'url': 'http://twitter.com/search?q=Italy', 'promoted_content': None, 'query': 'Italy', 'tweet_volume': 739925}, {'name': 'Coachella', 'url': 'http://twitter.com/search?q=Coachella', 'promoted_content': None, 'query': 'Coachella', 'tweet_volume': 170833}, {'name': 'COVID-19', 'url': 'http://twitter.com/search?q=COVID-19', 'promoted_content': None, 'query': 'COVID-19', 'tweet_volume': 1187035}, {'name': '#InternationalWomensDay', 'url': 'http://twitter.com/search?q=%23InternationalWomensDay', 'promoted_content': None, 'query': '%23InternationalWomensDay', 'tweet_volume': 194287}, {'name': '#BernieSurge', 'url': 'http://twitter.com/search?q=%23BernieSurge', 'promoted_content': None, 'query': '%23BernieSurge', 'tweet_volume': 19194}, {'name': 'NFL 2K', 'url': 'http://twitter.com/search?q=%22NFL+2K%22', 'promoted_content': None, 'query': '%22NFL+2K%22', 'tweet_volume': None}, {'name': 'Chuck Norris', 'url': 'http://twitter.com/search?q=%22Chuck+Norris%22', 'promoted_content': None, 'query': '%22Chuck+Norris%22', 'tweet_volume': 10657}, {'name': 'Marshal Yanda', 'url': 'http://twitter.com/search?q=%22Marshal+Yanda%22', 'promoted_content': None, 'query': '%22Marshal+Yanda%22', 'tweet_volume': None}, {'name': 'RIP Ollie', 'url': 'http://twitter.com/search?q=%22RIP+Ollie%22', 'promoted_content': None, 'query': '%22RIP+Ollie%22', 'tweet_volume': None}, {'name': 'China Virus', 'url': 'http://twitter.com/search?q=%22China+Virus%22', 'promoted_content': None, 'query': '%22China+Virus%22', 'tweet_volume': None}, {'name': 'Brandon Knight', 'url': 'http://twitter.com/search?q=%22Brandon+Knight%22', 'promoted_content': None, 'query': '%22Brandon+Knight%22', 'tweet_volume': None}, {'name': 'Bob Saget', 'url': 'http://twitter.com/search?q=%22Bob+Saget%22', 'promoted_content': None, 'query': '%22Bob+Saget%22', 'tweet_volume': None}, {'name': 'Trish Regan', 'url': 'http://twitter.com/search?q=%22Trish+Regan%22', 'promoted_content': None, 'query': '%22Trish+Regan%22', 'tweet_volume': 39325}, {'name': 'ESPN 2K5', 'url': 'http://twitter.com/search?q=%22ESPN+2K5%22', 'promoted_content': None, 'query': '%22ESPN+2K5%22', 'tweet_volume': None}, {'name': 'Morning Joke', 'url': 'http://twitter.com/search?q=%22Morning+Joke%22', 'promoted_content': None, 'query': '%22Morning+Joke%22', 'tweet_volume': None}, {'name': '2K Sports', 'url': 'http://twitter.com/search?q=%222K+Sports%22', 'promoted_content': None, 'query': '%222K+Sports%22', 'tweet_volume': None}, {'name': 'NCAA Football', 'url': 'http://twitter.com/search?q=%22NCAA+Football%22', 'promoted_content': None, 'query': '%22NCAA+Football%22', 'tweet_volume': None}, {'name': 'Charlie Sheen', 'url': 'http://twitter.com/search?q=%22Charlie+Sheen%22', 'promoted_content': None, 'query': '%22Charlie+Sheen%22', 'tweet_volume': None}, {'name': 'ortega smith', 'url': 'http://twitter.com/search?q=%22ortega+smith%22', 'promoted_content': None, 'query': '%22ortega+smith%22', 'tweet_volume': 104487}, {'name': '#TuesdayMotivation', 'url': 'http://twitter.com/search?q=%23TuesdayMotivation', 'promoted_content': None, 'query': '%23TuesdayMotivation', 'tweet_volume': 29525}, {'name': '#MAR10Day', 'url': 'http://twitter.com/search?q=%23MAR10Day', 'promoted_content': None, 'query': '%23MAR10Day', 'tweet_volume': 14724}, {'name': '#BidensCognitiveDecline', 'url': 'http://twitter.com/search?q=%23BidensCognitiveDecline ...

# %% [markdown]
# ## Example:3 Displaying API responses as pretty-printed JSON

# %%
import json
print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#BernieSurge",
#     "url": "http://twitter.com/search?q=%23BernieSurge",
#     "promoted_content": null,
#     "query": "%23BernieSurge",
#     "tweet_volume": 19194
#    },
#    {
#     "name": "#TuesdayMotivation",
#     "url": "http://twitter.com/search?q=%23TuesdayMotivation",
#     "promoted_content": null,
#     "query": "%23TuesdayMotivation",
#     "tweet_volume": 29525
#    },
#    {
#     "name": "#MAR10Day",
#     "url": "http://twitter.com/search?q=%23MAR10Day",
#     "promoted_content": null,
#     "query": "%23MAR10Day",
#     "tweet_volume": 14724
#    },
#    {
#     "name": "NFL 2K",
#     "url": "http://twitter.com/search?q=%22NFL+2K%22",
#     "promoted_content": null,
#     "query": "%22NFL+2K%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Chuck Norris",
#     "url": "http://twitter.com/search?q=%22Chuck+Norris%22",
#     "promoted_content": null,
#     "query": "%22Chuck+Norris%22",
#     "tweet_volume": 10657
#    },
#    {
#     "name": "#BidensCognitiveDecline",
#     "url": "http://twitter.com/search?q=%23BidensCognitiveDecline",
#     "promoted_content": null,
#     "query": "%23BidensCognitiveDecline",
#     "tweet_volume": 13530
#    },
#    {
#     "name": "#ThankYouNamjoon",
#     "url": "http://twitter.com/search?q=%23ThankYouNamjoon",
#     "promoted_content": null,
#     "query": "%23ThankYouNamjoon",
#     "tweet_volume": 285788
#    },
#    {
#     "name": "Marshal Yanda",
#     "url": "http://twitter.com/search?q=%22Marshal+Yanda%22",
#     "promoted_content": null,
#     "query": "%22Marshal+Yanda%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "RIP Ollie",
#     "url": "http://twitter.com/search?q=%22RIP+Ollie%22",
#     "promoted_content": null,
#     "query": "%22RIP+Ollie%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "China Virus",
#     "url": "http://twitter.com/search?q=%22China+Virus%22",
#     "promoted_content": null,
#     "query": "%22China+Virus%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brandon Knight",
#     "url": "http://twitter.com/search?q=%22Brandon+Knight%22",
#     "promoted_content": null,
#     "query": "%22Brandon+Knight%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Bob Saget",
#     "url": "http://twitter.com/search?q=%22Bob+Saget%22",
#     "promoted_content": null,
#     "query": "%22Bob+Saget%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Coronavirus Impeachment Scam",
#     "url": "http://twitter.com/search?q=%22Coronavirus+Impeachment+Scam%22",
#     "promoted_content": null,
#     "query": "%22Coronavirus+Impeachment+Scam%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Trish Regan",
#     "url": "http://twitter.com/search?q=%22Trish+Regan%22",
#     "promoted_content": null,
#     "query": "%22Trish+Regan%22",
#     "tweet_volume": 39325
#    },
#    {
#     "name": "ESPN 2K5",
#     "url": "http://twitter.com/search?q=%22ESPN+2K5%22",
#     "promoted_content": null,
#     "query": "%22ESPN+2K5%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Morning Joke",
#     "url": "http://twitter.com/search?q=%22Morning+Joke%22",
#     "promoted_content": null,
#     "query": "%22Morning+Joke%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "williamson county schools",
#     "url": "http://twitter.com/search?q=%22williamson+county+schools%22",
#     "promoted_content": null,
#     "query": "%22williamson+county+schools%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "2K Sports",
#     "url": "http://twitter.com/search?q=%222K+Sports%22",
#     "promoted_content": null,
#     "query": "%222K+Sports%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "NCAA Football",
#     "url": "http://twitter.com/search?q=%22NCAA+Football%22",
#     "promoted_content": null,
#     "query": "%22NCAA+Football%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Charlie Sheen",
#     "url": "http://twitter.com/search?q=%22Charlie+Sheen%22",
#     "promoted_content": null,
#     "query": "%22Charlie+Sheen%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "ortega smith",
#     "url": "http://twitter.com/search?q=%22ortega+smith%22",
#     "promoted_content": null,
#     "query": "%22ortega+smith%22",
#     "tweet_volume": 104487
#    },
#    {
#     "name": "Wheel of Fortune",
#     "url": "http://twitter.com/search?q=%22Wheel+of+Fortune%22",
#     "promoted_content": null,
#     "query": "%22Wheel+of+Fortune%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Darren Fells",
#     "url": "http://twitter.com/search?q=%22Darren+Fells%22",
#     "promoted_content": null,
#     "query": "%22Darren+Fells%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Super Twosday",
#     "url": "http://twitter.com/search?q=%22Super+Twosday%22",
#     "promoted_content": null,
#     "query": "%22Super+Twosday%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "christ as lord",
#     "url": "http://twitter.com/search?q=%22christ+as+lord%22",
#     "promoted_content": null,
#     "query": "%22christ+as+lord%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JillSteinIsARussianAsset",
#     "url": "http://twitter.com/search?q=%23JillSteinIsARussianAsset",
#     "promoted_content": null,
#     "query": "%23JillSteinIsARussianAsset",
#     "tweet_volume": null
#    },
#    {
#     "name": "#StrangeThingsInMyCloset",
#     "url": "http://twitter.com/search?q=%23StrangeThingsInMyCloset",
#     "promoted_content": null,
#     "query": "%23StrangeThingsInMyCloset",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MichiganVotes",
#     "url": "http://twitter.com/search?q=%23MichiganVotes",
#     "promoted_content": null,
#     "query": "%23MichiganVotes",
#     "tweet_volume": null
#    },
#    {
#     "name": "#DeleteTheirPhoneNumberIf",
#     "url": "http://twitter.com/search?q=%23DeleteTheirPhoneNumberIf",
#     "promoted_content": null,
#     "query": "%23DeleteTheirPhoneNumberIf",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AdviceToMeInHighSchool",
#     "url": "http://twitter.com/search?q=%23AdviceToMeInHighSchool",
#     "promoted_content": null,
#     "query": "%23AdviceToMeInHighSchool",
#     "tweet_volume": null
#    },
#    {
#     "name": "#todayanswers",
#     "url": "http://twitter.com/search?q=%23todayanswers",
#     "promoted_content": null,
#     "query": "%23todayanswers",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MissouriPrimary",
#     "url": "http://twitter.com/search?q=%23MissouriPrimary",
#     "promoted_content": null,
#     "query": "%23MissouriPrimary",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MyFavoriteClassicVideoGame",
#     "url": "http://twitter.com/search?q=%23MyFavoriteClassicVideoGame",
#     "promoted_content": null,
#     "query": "%23MyFavoriteClassicVideoGame",
#     "tweet_volume": null
#    },
#    {
#     "name": "#JungleCruise",
#     "url": "http://twitter.com/search?q=%23JungleCruise",
#     "promoted_content": null,
#     "query": "%23JungleCruise",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FCMostInnovative",
#     "url": "http://twitter.com/search?q=%23FCMostInnovative",
#     "promoted_content": null,
#     "query": "%23FCMostInnovative",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CelebrateAbortionProviders",
#     "url": "http://twitter.com/search?q=%23CelebrateAbortionProviders",
#     "promoted_content": null,
#     "query": "%23CelebrateAbortionProviders",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WeAreSPFE",
#     "url": "http://twitter.com/search?q=%23WeAreSPFE",
#     "promoted_content": null,
#     "query": "%23WeAreSPFE",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BookBirthday",
#     "url": "http://twitter.com/search?q=%23BookBirthday",
#     "promoted_content": null,
#     "query": "%23BookBirthday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#RIPOllie",
#     "url": "http://twitter.com/search?q=%23RIPOllie",
#     "promoted_content": null,
#     "query": "%23RIPOllie",
#     "tweet_volume": null
#    },
#    {
#     "name": "#FelizMartes",
#     "url": "http://twitter.com/search?q=%23FelizMartes",
#     "promoted_content": null,
#     "query": "%23FelizMartes",
#     "tweet_volume": 19612
#    },
#    {
#     "name": "#TMobileTuesdays",
#     "url": "http://twitter.com/search?q=%23TMobileTuesdays",
#     "promoted_content": null,
#     "query": "%23TMobileTuesdays",
#     "tweet_volume": null
#    },
#    {
#     "name": "#HoweAwardsxMG",
#     "url": "http://twitter.com/search?q=%23HoweAwardsxMG",
#     "promoted_content": null,
#     "query": "%23HoweAwardsxMG",
#     "tweet_volume": 69579
#    },
#    {
#     "name": "#SSGATL",
#     "url": "http://twitter.com/search?q=%23SSGATL",
#     "promoted_content": null,
#     "query": "%23SSGATL",
#     "tweet_volume": null
#    },
#    {
#     "name": "#MattGaetzIsAQuarantinedTool",
#     "url": "http://twitter.com/search?q=%23MattGaetzIsAQuarantinedTool",
#     "promoted_content": null,
#     "query": "%23MattGaetzIsAQuarantinedTool",
#     "tweet_volume": null
#    },
#    {
#     "name": "#NWGHAAD",
#     "url": "http://twitter.com/search?q=%23NWGHAAD",
#     "promoted_content": null,
#     "query": "%23NWGHAAD",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LArain",
#     "url": "http://twitter.com/search?q=%23LArain",
#     "promoted_content": null,
#     "query": "%23LArain",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CUNY",
#     "url": "http://twitter.com/search?q=%23CUNY",
#     "promoted_content": null,
#     "query": "%23CUNY",
#     "tweet_volume": null
#    },
#    {
#     "name": "#BidenSurge",
#     "url": "http://twitter.com/search?q=%23BidenSurge",
#     "promoted_content": null,
#     "query": "%23BidenSurge",
#     "tweet_volume": null
#    },
#    {
#     "name": "#payrolltaxcut",
#     "url": "http://twitter.com/search?q=%23payrolltaxcut",
#     "promoted_content": null,
#     "query": "%23payrolltaxcut",
#     "tweet_volume": null
#    },
#    {
#     "name": "#thenine",
#     "url": "http://twitter.com/search?q=%23thenine",
#     "promoted_content": null,
#     "query": "%23thenine",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2020-03-10T13:38:29Z",
#   "created_at": "2020-03-10T13:33:16Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example:4 Computing the intersting of two sets of trends

# %%
trends_set = {}
trends_set["world"] = set([trend["name"]
                          for trend in world_trends[0]["trends"]])

trends_set["us"] = set([trend["name"]
                       for trend in us_trends[0]["trends"]])

trends_set["san diego"] = set([trend["name"]
                              for trend in local_trends[0]["trends"]])

# %%
for loc in ["world", "us", "san diego"]:
    print(("-"*10,loc))
    print((",".join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #ひみ10,#RIPVuyo,Ollie,理想のキス,#elfinllegarácuando,うまかっちゃん,#マツコの知らない世界,#JyotiradityaScindia,#男子は引いて女子は足して,#ItaliaZonaRossa,声優おたく,#koronawirus,#SiJetaisMarioJe,#TuesdayThoughts,#このタグを見た人は習い事歴を晒せ,#ゆるニャン,#VaathiComing,#FKocaSağlıkçıyaMarttaAtama,#BernieSurge,#推しがちなキャラクターの特徴,#kuizyお絵描き診断,Chuck Norris,#FAAJI,#推し佐藤,#FelizMartes,DANIEL BROXANDO,#คั่นกูMV,#SB5CANDYCRUSH_TEASER,#AskRicci,#うたコン,#500DayswithSB19,#貴方の良い所と悪い所を神様から訊いた,スタレ,#恋はつづくよどこまでも,Ortega Smith,#نطالب_بايقاف_ابوطلال_الحمراني,#HoweAwardsxMG,#ThankYouNamjoon,#UbuhanSiDuterte,#和の文字で診断,プロ野球の球場,#cheltenham2020,#LobinTuketiciZirvesi,#nhk_jsclub,NFL 2K,#ORβITさん月が綺麗ですね,マンホール女優,#MAR10Day,#انقذو_ابو_سعد,#御伽の国の舞踏会
# ('----------', 'us')
# Bob Saget,Trish Regan,ortega smith,Darren Fells,#StrangeThingsInMyCloset,#MattGaetzIsAQuarantinedTool,#payrolltaxcut,#MyFavoriteClassicVideoGame,#BidensCognitiveDecline,#todayanswers,#NWGHAAD,#AdviceToMeInHighSchool,Morning Joke,#JungleCruise,#WeAreSPFE,China Virus,#TuesdayMotivation,#LArain,#CelebrateAbortionProviders,#BernieSurge,#FCMostInnovative,Chuck Norris,Marshal Yanda,christ as lord,#TMobileTuesdays,#SSGATL,2K Sports,#FelizMartes,Coronavirus Impeachment Scam,#DeleteTheirPhoneNumberIf,#BidenSurge,#RIPOllie,#HoweAwardsxMG,williamson county schools,#ThankYouNamjoon,#BookBirthday,#MichiganVotes,NCAA Football,NFL 2K,RIP Ollie,ESPN 2K5,#MissouriPrimary,#MAR10Day,Super Twosday,#CUNY,Wheel of Fortune,#thenine,#JillSteinIsARussianAsset,Brandon Knight,Charlie Sheen
# ('----------', 'san diego')
# Bob Saget,Trish Regan,ortega smith,#StrangeThingsInMyCloset,#MattGaetzIsAQuarantinedTool,UCSD,#payrolltaxcut,#MyFavoriteClassicVideoGame,#BidensCognitiveDecline,#todayanswers,#NWGHAAD,#AdviceToMeInHighSchool,Morning Joke,#InternationalWomensDay,#JungleCruise,#WeAreSPFE,China Virus,#TuesdayMotivation,#TheBachelor,#LArain,#CelebrateAbortionProviders,COVID-19,#BernieSurge,#FCMostInnovative,Chuck Norris,Marshal Yanda,#TMobileTuesdays,Coachella,2K Sports,#FelizMartes,#SSGATL,#DeleteTheirPhoneNumberIf,#BidenSurge,#RIPOllie,#HoweAwardsxMG,#ThankYouNamjoon,#BookBirthday,#MichiganVotes,NCAA Football,#COVID2019,NFL 2K,RIP Ollie,ESPN 2K5,#MissouriPrimary,#MAR10Day,#CUNY,Italy,#JillSteinIsARussianAsset,Brandon Knight,Charlie Sheen

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['san diego'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#BernieSurge', 'NFL 2K', 'Chuck Norris', '#MAR10Day', '#FelizMartes', '#HoweAwardsxMG', '#ThankYouNamjoon'}
# ('==========', 'intersection of us and san-diego')
# {'Bob Saget', 'Trish Regan', 'ortega smith', '#StrangeThingsInMyCloset', '#MattGaetzIsAQuarantinedTool', '#JillSteinIsARussianAsset', '#payrolltaxcut', '#MyFavoriteClassicVideoGame', '#BidensCognitiveDecline', '#todayanswers', '#NWGHAAD', '#AdviceToMeInHighSchool', 'Morning Joke', '#JungleCruise', '#WeAreSPFE', '#TuesdayMotivation', 'China Virus', '#LArain', '#CelebrateAbortionProviders', '#BernieSurge', '#FCMostInnovative', 'Chuck Norris', 'Marshal Yanda', '#TMobileTuesdays', '#SSGATL', '2K Sports', '#FelizMartes', '#DeleteTheirPhoneNumberIf', '#BidenSurge', '#RIPOllie', '#HoweAwardsxMG', '#ThankYouNamjoon', '#BookBirthday', '#MichiganVotes', 'NCAA Football', 'NFL 2K', 'RIP Ollie', 'ESPN 2K5', '#CUNY', '#MAR10Day', '#MissouriPrimary', 'Brandon Knight', 'Charlie Sheen'}

# %% [markdown]
# ## Example 5: Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = "#MTVAwards"
# topics = "#HoweAwardsxMG"

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets
search_results = twitter_api.search.tweets(q = q, count = number)
statuses = search_results["statuses"]

# %%
len(statuses)
# Out:
# 100

# %%
print(statuses)
# Out:
# [{'created_at': 'Tue Mar 10 13:56:41 +0000 2020', 'id': 1237376833890537472, 'id_str': '1237376833890537472', 'text': 'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9', 'truncated': False, 'entities': {'hashtags': [{'text': 'MTVAwards', 'indices': [64, 74]}], 'symbols': [], 'user_mentions': [{'screen_name': 'MTV', 'name': 'MTV', 'id': 2367911, 'id_str': '2367911', 'indices': [3, 7]}, {'screen_name': 'chloexhalle', 'name': 'chloe x halle', 'id': 189362860, 'id_str': '189362860', 'indices': [19, 31]}], 'urls': [], 'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [77, 100], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cDZ8kwmkF9', 'display_url': 'pic.twitter.com/cDZ8kwmkF9', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911'}]}, 'extended_entities': {'media': [{'id': 1008838927623417856, 'id_str': '1008838927623417856', 'indices': [77, 100], 'media_url': 'http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'media_url_https': 'https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg', 'url': 'https://t.co/cDZ8kwmkF9', 'display_url': 'pic.twitter.com/cDZ8kwmkF9', 'expanded_url': 'https://twitter.com/MTV/status/1008887184684822528/video/1', 'type': 'video', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 675, 'resize': 'fit'}, 'small': {'w': 680, 'h': 383, 'resize': 'fit'}, 'large': {'w': 1280, 'h': 720, 'resize': 'fit'}}, 'source_status_id': 1008887184684822528, 'source_status_id_str': '1008887184684822528', 'source_user_id': 2367911, 'source_user_id_str': '2367911', 'video_info': {'aspect_ratio': [16, 9], 'duration_millis': 212345, 'variants': [{'content_type': 'application/x-mpegURL', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2'}, {'bitrate': 832000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2'}, {'bitrate': 320000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2'}, {'bitrate': 2176000, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2'}]}, 'additional_media_info': {'title': '', 'description': '', 'embeddable': True, 'monetizable': True, 'source_user': {'id': 2367911, 'id_str': '2367911', 'name': 'MTV', 'screen_name': 'MTV', 'location': 'NYC', 'description': 'Let me make you a mixtape', 'url': 'https://t.co/yyniasrs2z', 'entities': {'url': {'urls': [{'url': 'https://t.co/yyniasrs2z', 'expanded_url': 'http://mtv.com', 'display_url': 'mtv.com', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 15826346, 'friends_count': 31527, 'listed_count': 31533, 'created_at': 'Mon Mar 26 22:30:49 +0000 2007', 'favourites_count': 19834, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': True, 'statuses_count': 287493, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': True, 'profile_background_color': '131516', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg', 'profile_i ...

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 43

# %%
[s["text"] for s in search_results["statuses"]]
# Out:
# ['RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTV: @CW_Riverdale did you hear the news? #riverdale has been nominated at the 2018 #mtvawards! cast your votes at https://t.co/B6c16HK…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar…",
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar…",
#  "WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the… https://t.co/YgmzN4NOFx",
#  'RT @WolverineMovie: Like father, like daughter. @RealHughJackman &amp; @DafneKeen win #MTVAwards for Best Duo. #Logan https://t.co/yKnXIWc3kn',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'Out of all the #popvinylfigures we got think this may be our favourite #mtv #moonperson #spaceman #MTVawards https://t.co/EPiFwFLhyX',
#  'RT @MTVAwards: Killer on the carpet, killer in the ring. @BeckyLynchWWE 👠🥊 \n\nLess than an hour until the #MTVAwards ❗️9p on @MTV 🙌 https://…',
#  'RT @MTVteenwolf: 🚨 ALERT 🚨 The #TeenWolf cast at the #MTVAwards over years will always be CUTE AS HECK! Catch the show Monday, June 17th at…',
#  'Los #SpotifyAwards2020 son los nuevos #MtvAwards cuando lo hacían en el palacio de los deportes.',
#  'RT @daenerwszx: O que essa obra de arte esta fazendo fora do museu #MTVAwards https://t.co/SkMSBCKivn',
#  'RT @daenerwszx: ESSA MULHER É MARAVILHOSA, AMÉM KATHERINE LANGFORD  #MTVAwards https://t.co/7dgW0dc7R1',
#  'RT @daenerwszx: tyler posey tirando foto com os fãs na chuva é a minha religião  #MTVAwards https://t.co/KnZIoQSsvR',
#  'RT @daenerwszx: #MTVAwards https://t.co/MrNqggTNOf',
#  'RT @daenerwszx: UM ELENCO MARAVILHOSO DESSES BICHO  #MTVAwards https://t.co/rOshAWSk3P',
#  'Antes era los #MTvAwards y ahora la plataforma con mayor influencia en #Musica. Los #SpotifyAwards no son solo un e… https://t.co/PNFqifomFN',
#  'El artista más escuchado de los #SpotifyAwards2020 es Bad Bunny.\n\nEn mi época, Madonna la artista que la rompió en los #MTVAwards de los 80.',
#  'Los #SpotifyAwards un intento de lo que eran los #mtvawards',
#  "RT @MTVAwards: From @lizzo to @brielarson and more...here are the BEST audience reactions of the 2019 #MTVAwards\n\nFind out what they're rea…",
#  'RT @MTVAwards: 😱MOST FRIGHTENED PERFORMANCE GOES TO....😱\n\n#SandraBullock in "Bird Box" #MTVAwards https://t.co/P2qNbSfZBQ',
#  'RT @sanbullockof: SOCORRO MDS AAAAAA #MTVAwards https://t.co/jSEoQOqNEh',
#  'RT @MTV: "Family is what you fight for, family is what you protect. What you see in this film is exactly what Mommy would do for you." -San…',
#  'RT @MTV: Is it too late for Sandra Bullock to adopt me?! #MTVAwards https://t.co/Qx6sUB9Xbx',
#  'RT @sanbullockof: Gente qual a outra categoria que a Sandra está concorrendo? #MTVAwards',
#  'RT @sanbullockof: Vocês viram a cara da Melissa vendo a Sandra falar AAAA ela admira muito a sandy 🤧 #MTVAwards',
#  'RT @sanbullockof: VOCÊS VIRAM O BRYAN AAAAAA LINDO MDS #MTVAwards',
#  'RT @MTVAwards: GIVE IT UP FOR ALL THESE LADIES 👏  \n\nWhat would you do to sit at this table? #MTVAwards https://t.co/aubaNfy2x0',
#  'RT @sanbullockof: A PRÓXIMA CATEGORIA É A QUE A SANDRA ESTÁ CONCORRENDO AAAAAA NERVOSA #MTVAwards',
#  'RT @MTVBrasil: E quem vai levar para casa o prêmio de MELHOR ATUAÇÃO ASSUSTADA é a linda da Sandra Bullock! 👏👏👏  #MTVAwards https://t.co/ke…',
#  'RT @CaptMarvelBR: 📹 | O PESO DESSE VÍDEO!\n\nSandra Bullock grata pelo reconhecimento do seu trabalho, o que a possibilita levar seu filho, f…',
#  'RT @sanbullockof: BOA NOITE FANDOM ATÉ O OSCAR KKKK #MTVAwards https://t.co/Ryhvz4sVeu',
#  'RT @etnow: Sandra Bullock reveals she made Bird Box for her kids and her family 😭 #MTVAwards https://t.co/8P4Uycd1GM',
#  'RT @MTVAwards: #SandraBullock dedicated her #MTVAward for Most Frightened Performance in "Bird Box" to her family 💖\n\n#MTVAwards https://t.c…',
#  'RT @LHHRealitea: #LHHATL WONNNN!!!!!!!! 🔥🙌🏽 #MTVAwards #LHHATL https://t.co/ood4yx8ld7',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @dunevillenuve: chloe and halle are angels beyoncé really did bless them #mtvawards  https://t.co/y2fDHMj3rs',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  "Checklist- Normani  \nThis song should've gotten more promo then we would've gotten more performances looked this… https://t.co/2PmcklmIdT",
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @MTV: Let @dylanobrien guide you through a first look at Maze Runner: The Death Cure, exclusively for the #MTVAwards tonight at 8/7c! 💥…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @TheRock: Thanks man. Inspired tears are a good thing. Now go have some tequila 🥃 \n#MTVAwards https://t.co/zk7jmYBomu',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @soniagracemusic: #MTVAwards\nIn honor of the #VMAs #MTVVMAs https://t.co/B6zp8yO0iX',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  "RT @MTV: 💋HAPPY VALENTINE'S DAY 💋\n\nPls enjoy these super sweet smooches from our Best Kiss winners at the #MTVAwards!!! https://t.co/pexc84…",
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards 😍 https://t.co/cDZ8kwmkF9',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTV: YES! Girl Power!! @brielarson #MTVAwards https://t.co/QHBKbpNJe0',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…',
#  'RT @MTVAwards: Remember that time @GatenM123 almost spoiled the third season of #StrangerThings at the #MTVAwards? 😂😅 https://t.co/NbRJ4nvQ…']

# %%
# Show one sample search result by slicing the list
print(json.dumps(statuses[0],indent = 1))
# Out:
# {
#  "created_at": "Tue Mar 10 13:56:41 +0000 2020",
#  "id": 1237376833890537472,
#  "id_str": "1237376833890537472",
#  "text": "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "MTVAwards",
#     "indices": [
#      64,
#      74
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "MTV",
#     "name": "MTV",
#     "id": 2367911,
#     "id_str": "2367911",
#     "indices": [
#      3,
#      7
#     ]
#    },
#    {
#     "screen_name": "chloexhalle",
#     "name": "chloe x halle",
#     "id": 189362860,
#     "id_str": "189362860",
#     "indices": [
#      19,
#      31
#     ]
#    }
#   ],
#   "urls": [],
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      77,
#      100
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cDZ8kwmkF9",
#     "display_url": "pic.twitter.com/cDZ8kwmkF9",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "photo",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911"
#    }
#   ]
#  },
#  "extended_entities": {
#   "media": [
#    {
#     "id": 1008838927623417856,
#     "id_str": "1008838927623417856",
#     "indices": [
#      77,
#      100
#     ],
#     "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#     "url": "https://t.co/cDZ8kwmkF9",
#     "display_url": "pic.twitter.com/cDZ8kwmkF9",
#     "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#     "type": "video",
#     "sizes": {
#      "thumb": {
#       "w": 150,
#       "h": 150,
#       "resize": "crop"
#      },
#      "medium": {
#       "w": 1200,
#       "h": 675,
#       "resize": "fit"
#      },
#      "small": {
#       "w": 680,
#       "h": 383,
#       "resize": "fit"
#      },
#      "large": {
#       "w": 1280,
#       "h": 720,
#       "resize": "fit"
#      }
#     },
#     "source_status_id": 1008887184684822528,
#     "source_status_id_str": "1008887184684822528",
#     "source_user_id": 2367911,
#     "source_user_id_str": "2367911",
#     "video_info": {
#      "aspect_ratio": [
#       16,
#       9
#      ],
#      "duration_millis": 212345,
#      "variants": [
#       {
#        "content_type": "application/x-mpegURL",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#       },
#       {
#        "bitrate": 832000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#       },
#       {
#        "bitrate": 320000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#       },
#       {
#        "bitrate": 2176000,
#        "content_type": "video/mp4",
#        "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#       }
#      ]
#     },
#     "additional_media_info": {
#      "title": "",
#      "description": "",
#      "embeddable": true,
#      "monetizable": true,
#      "source_user": {
#       "id": 2367911,
#       "id_str": "2367911",
#       "name": "MTV",
#       "screen_name": "MTV",
#       "location": "NYC",
#       "description": "Let me make you a mixtape",
#       "url": "https://t.co/yyniasrs2z",
#       "entities": {
#        "url": {
#         "urls": [
#          {
#           "url": "https://t.co/yyniasrs2z",
#           "expanded_url": "http://mtv.com",
#           "display_url": "mtv.com",
#           "indices": [
#            0,
#            23
#           ]
#          }
#         ]
#        },
#        "description": {
#         "urls": []
#        }
#       },
#       "protected": false,
#       "followers_count": 15826346,
#       "friends_count": 31527,
#       "listed_count": 31533,
#       "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#       "favourites_count": 19834,
#       "utc_offset": null,
#       "time_zone": null,
#       "geo_enabled": true,
#       "verified": true,
#       "statuses_count": 287493,
#       "lang": null,
#       "contributors_enabled": false,
#       "is_translator": false,
#       "is_translation_enabled": true,
#       "profile_background_color": "131516",
#       "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#       "profile_background_tile": true,
#       "profile_image_url": "http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#       "profile_image_url_https": "https://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#       "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1582150942",
#       "profile_link_color": "009999",
#       "profile_sidebar_border_color": "FFFFFF",
#       "profile_sidebar_fill_color": "EFEFEF",
#       "profile_text_color": "333333",
#       "profile_use_background_image": true,
#       "has_extended_profile": false,
#       "default_profile": false,
#       "default_profile_image": false,
#       "following": false,
#       "follow_request_sent": false,
#       "notifications": false,
#       "translator_type": "regular"
#      }
#     }
#    }
#   ]
#  },
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/iphone\" rel=\"nofollow\">Twitter for iPhone</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 994747219990499328,
#   "id_str": "994747219990499328",
#   "name": "\ud835\udcae\ud835\udcbd\ud835\udcb6\ud835\udcc3\ud835\udcc3\ud835\udc5c\ud835\udcc3",
#   "screen_name": "_shaannonn_",
#   "location": "",
#   "description": "",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 248,
#   "friends_count": 456,
#   "listed_count": 0,
#   "created_at": "Fri May 11 01:13:13 +0000 2018",
#   "favourites_count": 1812,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": false,
#   "statuses_count": 889,
#   "lang": null,
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1217617730838450177/ZvS3DmCN_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1217617730838450177/ZvS3DmCN_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/994747219990499328/1579137664",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Tue Jun 19 01:40:23 +0000 2018",
#   "id": 1008887184684822528,
#   "id_str": "1008887184684822528",
#   "text": "My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#   "truncated": false,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "MTVAwards",
#      "indices": [
#       55,
#       65
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "chloexhalle",
#      "name": "chloe x halle",
#      "id": 189362860,
#      "id_str": "189362860",
#      "indices": [
#       10,
#       22
#      ]
#     }
#    ],
#    "urls": [],
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       68,
#       91
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cDZ8kwmkF9",
#      "display_url": "pic.twitter.com/cDZ8kwmkF9",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "photo",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      }
#     }
#    ]
#   },
#   "extended_entities": {
#    "media": [
#     {
#      "id": 1008838927623417856,
#      "id_str": "1008838927623417856",
#      "indices": [
#       68,
#       91
#      ],
#      "media_url": "http://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "media_url_https": "https://pbs.twimg.com/media/DgAoXVXVQAA0LT6.jpg",
#      "url": "https://t.co/cDZ8kwmkF9",
#      "display_url": "pic.twitter.com/cDZ8kwmkF9",
#      "expanded_url": "https://twitter.com/MTV/status/1008887184684822528/video/1",
#      "type": "video",
#      "sizes": {
#       "thumb": {
#        "w": 150,
#        "h": 150,
#        "resize": "crop"
#       },
#       "medium": {
#        "w": 1200,
#        "h": 675,
#        "resize": "fit"
#       },
#       "small": {
#        "w": 680,
#        "h": 383,
#        "resize": "fit"
#       },
#       "large": {
#        "w": 1280,
#        "h": 720,
#        "resize": "fit"
#       }
#      },
#      "video_info": {
#       "aspect_ratio": [
#        16,
#        9
#       ],
#       "duration_millis": 212345,
#       "variants": [
#        {
#         "content_type": "application/x-mpegURL",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/pl/qFNZ76ZY2Xb0FvzB.m3u8?tag=2"
#        },
#        {
#         "bitrate": 832000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/640x360/U0Itn-R3zjzw7U4C.mp4?tag=2"
#        },
#        {
#         "bitrate": 320000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/320x180/VrdbgndrNzhhKTm-.mp4?tag=2"
#        },
#        {
#         "bitrate": 2176000,
#         "content_type": "video/mp4",
#         "url": "https://video.twimg.com/amplify_video/1008838927623417856/vid/1280x720/Ipod6v-8yamlP5Q7.mp4?tag=2"
#        }
#       ]
#      },
#      "additional_media_info": {
#       "title": "",
#       "description": "",
#       "embeddable": true,
#       "monetizable": true
#      }
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"https://studio.twitter.com\" rel=\"nofollow\">Twitter Media Studio</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 2367911,
#    "id_str": "2367911",
#    "name": "MTV",
#    "screen_name": "MTV",
#    "location": "NYC",
#    "description": "Let me make you a mixtape",
#    "url": "https://t.co/yyniasrs2z",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/yyniasrs2z",
#        "expanded_url": "http://mtv.com",
#        "display_url": "mtv.com",
#        "indices": [
#         0,
#         23
#        ]
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 15826346,
#    "friends_count": 31527,
#    "listed_count": 31533,
#    "created_at": "Mon Mar 26 22:30:49 +0000 2007",
#    "favourites_count": 19834,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": true,
#    "statuses_count": 287493,
#    "lang": null,
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": true,
#    "profile_background_color": "131516",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme14/bg.gif",
#    "profile_background_tile": true,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/1201467330611601411/vEfmYDcE_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/2367911/1582150942",
#    "profile_link_color": "009999",
#    "profile_sidebar_border_color": "FFFFFF",
#    "profile_sidebar_fill_color": "EFEFEF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "regular"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 4556,
#   "favorite_count": 11325,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "en"
#  },
#  "is_quote_status": false,
#  "retweet_count": 4556,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "possibly_sensitive": false,
#  "lang": "en"
# }

# %%
# lt of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t["retweet_count"])
print(t["retweeted"])
# Out:
# 4556
# False

# %% [markdown]
# ## Example 6: Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [status["text"]
               for status in statuses]

screen_names = [user_mention["screen_name"]
               for status in statuses
                   for user_mention in status["entities"]["user_mentions"]]

hashtags = [ hashtag["text"]
           for status in statuses
               for hashtag in status["entities"]["hashtags"] ]

# compute a collection of all words from all tweets
words = [w
          for t in status_texts
               for w in t.split()]

# %%
# Exploring the first 5 items for each.....

print(json.dumps(status_texts[0:5], indent =1))
print(json.dumps(screen_names[0:5], indent =1))
print(json.dumps(hashtags[0:5], indent =1))
print(json.dumps(words[0:5], indent =1))
# Out:
# [
#  "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "RT @MTV: @CW_Riverdale did you hear the news? #riverdale has been nominated at the 2018 #mtvawards! cast your votes at https://t.co/B6c16HK\u2026",
#  "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M\u2026",
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar\u2026"
# ]
# [
#  "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "RT @MTV: @CW_Riverdale did you hear the news? #riverdale has been nominated at the 2018 #mtvawards! cast your votes at https://t.co/B6c16HK\u2026",
#  "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M\u2026",
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar\u2026"
# ]
# [
#  "RT @MTV: My queens @chloexhalle slayed their performance at the #MTVAwards \ud83d\ude0d https://t.co/cDZ8kwmkF9",
#  "RT @MTV: @CW_Riverdale did you hear the news? #riverdale has been nominated at the 2018 #mtvawards! cast your votes at https://t.co/B6c16HK\u2026",
#  "RT @cxhupdates: Chloe and Halle performing at the #MTVAwards https://t.co/cZHo1RiYxU",
#  "RT @Lupita_Nyongo: Thank you @MTV for my Best Performance and Best Villain #UsMovie nominations, and for recognizing the film in the Best M\u2026",
#  "RT @MTVAwards: WE ARE ALL TRAILBLAZERS!\n\nThis #InternationalWomensDay we're looking back at @jadapsmith's incredible speech at the #MTVAwar\u2026"
# ]
